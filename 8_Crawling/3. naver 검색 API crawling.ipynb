# %%
import urllib.request
import bs4
import os
import sys

# %%
client_id = "20uqHAr39TBYdOu4URT"
client_secret = "lI2Bsf3dps"
encText = urllib.parse.quote("쿠팡")
url ="https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EC%97%90%EC%96%B4%EC%BB%A8"

# %%
request = urllib.request.Request(url)

# %%
request.add_header("X-Naver.Client-Id", client_id)
request.add_header("X-Naver.Client-Secret", client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

# %%
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="에어컨 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'에어컨'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'에어컨'의 네이버 통합검색 결과입니다."> <title>에어컨 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_191205.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_191010.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/api_atcmp_190612.css"><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError('"this" is null or not defined'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + "; expires=" + exdate.toUTCString(); } } cookie = cookie + "; path=/"; if (domain != null) { cookie = cookie + "; domain=" + domain; } document.cookie = cookie; }, get : function (key) { var cookie_list = document.cookie.split(/\s*;\s*/); for (var i = 0; i < cookie_list.length; i++) { var tmp_list = cookie_list[i].split("="); var c_key = tmp_list[0].trim(); var c_value = tmp_list[1]; if (key == c_key) { return unescape(c_value); } } return null; } } })(); naver.search.https = window.location.protocol == "https:"; naver.search.meta_referrer = 0; var _nx_js_load = (function () { var scrs = {} ; return  ...
#   <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#       if (_elAdIndLayerPl) {
#         adInfoHidePl();
#         return false;
#       } else {
#         if (!_elDscNcautionPl) {
#           _elDscNcautionPl = $Element(el).parent();
#         }
#         _elDscNcautionPl._element.style.zIndex = 121;
#         _elAdIndLayerPl = $Element(el).next();
#         _elAdIndLayerPl.show();
#         _elAdIndLayerTimePl = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHidePl() {
#       if (_elAdIndLayerPl) {
#         if (_elDscNcautionPl) {
#           _elDscNcautionPl._element.style.zIndex = 0;
#         }
#         _elAdIndLayerPl.hide();
#         _elAdIndLayerPl = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#       if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
#   </script>
#   <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/sa/190812/css/sa.css">
#   <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css">
#   <div class="ad_section section _pl_section bg_type_v2">
#     <div class="section_head nx_power"><h2>파워링크</h2>
#
#       <div class="dsc_ncaution">
#         <span><em class="dsc_ncaution_quotation">&lsquo;</em><strong class="dsc_ncaution_keyword">에어컨</strong><em
#                 class="dsc_ncaution_quotation">&rsquo;</em></span>
#         <span class="dsc_ncaution_text">관련 광고입니다.</span>
#         <a href="javascript:void(0);" class="ico_ad_dsc"
#            title="이 광고가 표시된 이유" onclick="if(adInfoShowPl(this)) goOtherCR(this, &#39;a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u=&#39;+urlencode(this.href));">이 광고가 표시된 이유</a>
#
#         <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none"><span class="ico_arr">&nbsp;</span>
#
#           <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,
#             이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다. <a href="https://saedu.naver.com/help/faq/ncc/view.nhn?faqSeq=704" class="link_help">도움말</a></p>
#           <button type="button" class="bt_ad_clse">안내 레이어 닫기</button>
#         </div>
#       </div>
#       <a href="//saedu.naver.com/adbiz/searchad/intro.nhn" class="go_register space" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u=&#39;+urlencode(this.href));">등록
#         안내</a>
#     </div>
#     <div class="ad_area nx_power" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=...">
#       <ul class="lst_type">
#         <li class="lst lst1  ext_link    "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="0">
#
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=sNOXpsyYuWHlHMfDePMdCP///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_tit"
#                onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000072651735&amp;d=&#39; + urlencode(&#39;http://www.auction.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">에어컨 옥션</a>
#
#
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=sNOXpsyYuWHlHMfDePMdCP///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000072651735&amp;d=&#39;+urlencode(&#39;http://www.auction.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.auction.co.kr</a>
#
#             </div>
#
#             <ul class="lst_link">
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=9rfQ94rvduN9whUW5Unbh////w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink1&amp;r=1&amp;i=nad-a001-01-000000072651735&amp;d=&#39;+urlencode(&#39;http://www.auction.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">옥션BEST</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=1sZxkHtmvkUlD94KAkDWiP///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink2&amp;r=1&amp;i=nad-a001-01-000000072651735&amp;d=&#39;+urlencode(&#39;http://www.auction.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">첫구매 혜택</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=fke60DK5ySEXHQCKLokGdf///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink3&amp;r=1&amp;i=nad-a001-01-000000072651735&amp;d=&#39;+urlencode(&#39;http://www.auction.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">스마일클럽</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=49edUuV4MTMgXykMmikgwP///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink4&amp;r=1&amp;i=nad-a001-01-000000072651735&amp;d=&#39;+urlencode(&#39;http://www.auction.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">당일배송</a>
#                 </li>
#
#             </ul>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               쇼핑이 생각날땐, 어서옥션! <strong class='hl'>에어컨</strong>, ALLKILL특가+스마일클럽 최대12%할인
#
#             </p></div>
#
#
#
#           </div>
#         </li>
#         <li class="lst lst2    ext_price type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="1">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=U3pVI2DTadW2Jr2CA+rTm////w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=2&amp;i=nad-a001-01-000000069883770&amp;d=&#39;+urlencode(&#39;http://ohou.se&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img src="https://searchad-phinf.pstatic.net/MjAxOTA4MjFfMjMw/MDAxNTY2MzU2MDEyNjI2.P-NNB-x2flVw-VqFNxLE19YP05gXpdh3Pf87ON0EfTEg.XrvBaAP-3Dee3YIdtv1Gdq48I7iQp6b3LDGTsKh3aCkg.PNG/1604249-ab8ba868-971e-4138-8939-8563c5bdc988.png?type=f120_120" width="60" height="60" alt="링크이미지" class="img_thumb">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=LK23NQjkfRXLFvCr/Ewznf///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_tit"
#                onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000069883770&amp;d=&#39; + urlencode(&#39;http://ohou.se&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">에어컨, 오늘의집</a>
#
#
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=LK23NQjkfRXLFvCr/Ewznf///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000069883770&amp;d=&#39;+urlencode(&#39;http://ohou.se&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">ohou.se</a>
#               <span class="ico_area">
#
#                 <span class="ico">
#                   <span class="sp_ad ico_nlogin" tabindex="0"
#                         onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                         onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);"
#                         onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                         onBlur="NAVER.SEARCH_AD.hideTooltip(this);">네이버 로그인</span>
#                   <a href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" class="ly_ad _tooltip"
#                      style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                      onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                      onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                      onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=pwl_nop.naverlogin&amp;r=2&amp;i=nad-a001-01-000000069883770&amp;u=&#39;+urlencode(this.href));">
#                     <span class="ly_box">
#                       <p>네이버 아이디로 로그인이 가능합니다.</p>
#                       <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
#                     </span>
#                       <span class="sp_ad ly_tail"></span>
#                   </a>
#                 </span>
#
#
#               </span>
#             </div>
#
#
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               이번주 한정! 인기상품 최대 90% 특가할인! <strong class='hl'>에어컨</strong>
#
#             </p></div>
#             <ul class="lst_price">
#
#                 <li class="item">
#                   <a href="https://adcr.naver.com/adcr?x=8xMBqd76p4uKxy7GI/L6G////w==..." class="link"
#                      target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.pricelink1&amp;r=2&amp;i=nad-a001-01-000000069883770&amp;d=&#39;+urlencode(&#39;http://ohou.se&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                     <span class="price">700원부터</span>
#                     <div class="txt">
#                       <span class="txt_inner">겨울얼리버드 최저가전</span>
#                     </div>
#                   </a>
#                 </li>
#
#                 <li class="item">
#                   <a href="https://adcr.naver.com/adcr?x=hF7fYU7nisAane4EY6brnf///w==..." class="link"
#                      target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.pricelink2&amp;r=2&amp;i=nad-a001-01-000000069883770&amp;d=&#39;+urlencode(&#39;http://ohou.se&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                     <span class="price">1,000원부터</span>
#                     <div class="txt">
#                       <span class="txt_inner">만능살림템 특가전</span>
#                     </div>
#                   </a>
#                 </li>
#
#                 <li class="item">
#                   <a href="https://adcr.naver.com/adcr?x=G9ZMADGWVBeMSeeEFWpYh////w==..." class="link"
#                      target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.pricelink3&amp;r=2&amp;i=nad-a001-01-000000069883770&amp;d=&#39;+urlencode(&#39;http://ohou.se&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                     <span class="price">990원부터</span>
#                     <div class="txt">
#                       <span class="txt_inner">크리스마스 기획전</span>
#                     </div>
#                   </a>
#                 </li>
#
#             </ul>
#
#
#           </div>
#         </li>
#         <li class="lst lst3   ext_desc  type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="2">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=at4vyLpZW+4P7y1jr6VRa////w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=3&amp;i=nad-a001-01-000000078384067&amp;d=&#39;+urlencode(&#39;http://www.wemakeprice.com/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img src="https://searchad-phinf.pstatic.net/MjAxOTA4MjJfMjk1/MDAxNTY2NDY0MTAzMzU0.ADlDlqiyKOIhoi8WrJagghUXiPgTR0StY38cLx8LAdYg.h9jfYESUqdm7VLCOYUZSL9ahlay9k2X9BxiSwVM5HAMg.PNG/925360-3c29ab99-27d5-4db9-911f-9102bbfae274.png?type=f120_120" width="60" height="60" alt="링크이미지" class="img_thumb">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=jBO1KEcFtZjuDqACoeW32v///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_tit"
#                onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000078384067&amp;d=&#39; + urlencode(&#39;http://www.wemakeprice.com/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">에어컨 위메프</a>
#
#
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=jBO1KEcFtZjuDqACoeW32v///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000078384067&amp;d=&#39;+urlencode(&#39;http://www.wemakeprice.com/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.wemakeprice.com/</a>
#
#             </div>
#             <p class="ad_dsc promotion">
#               <em class="point">이벤트</em>
#               특가클럽 2% 상시 적립!
#             </p>
#
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               초저가 도전! 역대급 할인 혜택! 할인쿠폰+무료배송+한정수량 <strong class='hl'>에어컨</strong>
#
#             </p></div>
#
#
#
#           </div>
#         </li>
#         <li class="lst lst4    ext_price type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="3">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=pzhrdidLqJkzqHBcf2stS////w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=4&amp;i=nad-a001-01-000000072943952&amp;d=&#39;+urlencode(&#39;http://rentalera.shop&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img src="https://searchad-phinf.pstatic.net/MjAxOTA4MzBfMjE2/MDAxNTY3MTQ5MjM5MDcx.AlhGs6iSGZTlHgijlGp7hvrBh-VeXwPPCgljHjm7vfAg.ge8fcXj-lyIcYYEzn0zQ3AXM52HKVWgArPt0YlImFyMg.JPEG/1382546-49cafae4-a327-4faa-bfe9-c90ce0472113.JPG?type=f120_120" width="60" height="60" alt="링크이미지" class="img_thumb">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=Owwjru0KrA8yZY2LDIJf5P///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_tit"
#                onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000072943952&amp;d=&#39; + urlencode(&#39;http://rentalera.shop&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">최신가전렌탈은 렌탈시대</a>
#
#
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=Owwjru0KrA8yZY2LDIJf5P///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000072943952&amp;d=&#39;+urlencode(&#39;http://rentalera.shop&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">rentalera.shop</a>
#
#             </div>
#
#
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               <strong class='hl'>에어컨</strong>,월 렌탈료 할인, 제휴카드할인혜택, 24시간 상담, 역대급 사은품증정
#
#             </p></div>
#             <ul class="lst_price">
#
#                 <li class="item">
#                   <a href="https://adcr.naver.com/adcr?x=gN8K2mORORuQusZJ0nkoh////w==..." class="link"
#                      target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.pricelink1&amp;r=4&amp;i=nad-a001-01-000000072943952&amp;d=&#39;+urlencode(&#39;http://rentalera.shop&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                     <span class="price">11,300원부터</span>
#                     <div class="txt">
#                       <span class="txt_inner">최신 벽걸이 에어컨</span>
#                     </div>
#                   </a>
#                 </li>
#
#                 <li class="item">
#                   <a href="https://adcr.naver.com/adcr?x=5DPnAv4/MaXsOEBfBs4pZv///w==..." class="link"
#                      target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.pricelink2&amp;r=4&amp;i=nad-a001-01-000000072943952&amp;d=&#39;+urlencode(&#39;http://rentalera.shop&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                     <span class="price">32,900원부터</span>
#                     <div class="txt">
#                       <span class="txt_inner">최신 스탠드 에어컨</span>
#                     </div>
#                   </a>
#                 </li>
#
#                 <li class="item">
#                   <a href="https://adcr.naver.com/adcr?x=6T4bv3pcQGHvibAB78H31f///w==..." class="link"
#                      target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.pricelink3&amp;r=4&amp;i=nad-a001-01-000000072943952&amp;d=&#39;+urlencode(&#39;http://rentalera.shop&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                     <span class="price">39,900원부터</span>
#                     <div class="txt">
#                       <span class="txt_inner">최신 투인원 에어컨</span>
#                     </div>
#                   </a>
#                 </li>
#
#             </ul>
#
#
#           </div>
#         </li>
#         <li class="lst lst5  ext_link   type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="4">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=lkd7m/radwa0wtCilY62gP///w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=5&amp;i=nad-a001-01-000000080624807&amp;d=&#39;+urlencode(&#39;http://WWW.e-HIMART.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img src="https://searchad-phinf.pstatic.net/MjAxOTExMDFfMTY4/MDAxNTcyNjA3MDc0MDM1.Y1E81zaxwZUcqM7Yc3NJuGryc2fRA0l1Wpb524tE1esg.cq-brwqJXELJngGOT8yFgJesvtQ5oWoTXrUloLlA4Lsg.JPEG/418677-1e69a17d-bc25-41a9-bb77-eb2be0a02ff3.jpg?type=f120_120" width="60" height="60" alt="링크이미지" class="img_thumb">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=U3JmNfiCGPnFhGx0d2r8c////w==...&amp;p=0"
#                target="_blank"
#                class="lnk_tit"
#                onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=5&amp;i=nad-a001-01-000000080624807&amp;d=&#39; + urlencode(&#39;http://WWW.e-HIMART.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">하이마트 에어컨</a>
#
#
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=U3JmNfiCGPnFhGx0d2r8c////w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000080624807&amp;d=&#39;+urlencode(&#39;http://WWW.e-HIMART.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">WWW.e-HIMART.co.kr</a>
#               <span class="ico_area">
#
#                 <span class="ico">
#                   <span class="sp_ad ico_nlogin" tabindex="0"
#                         onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                         onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);"
#                         onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                         onBlur="NAVER.SEARCH_AD.hideTooltip(this);">네이버 로그인</span>
#                   <a href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" class="ly_ad _tooltip"
#                      style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                      onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                      onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                      onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=pwl_nop.naverlogin&amp;r=5&amp;i=nad-a001-01-000000080624807&amp;u=&#39;+urlencode(this.href));">
#                     <span class="ly_box">
#                       <p>네이버 아이디로 로그인이 가능합니다.</p>
#                       <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
#                     </span>
#                       <span class="sp_ad ly_tail"></span>
#                   </a>
#                 </span>
#
#
#               </span>
#             </div>
#
#             <ul class="lst_link">
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=S+zu++gJ50KPaQBID6twHf///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink1&amp;r=5&amp;i=nad-a001-01-000000080624807&amp;d=&#39;+urlencode(&#39;http://WWW.e-HIMART.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">스마트픽</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=IS6dMsowIywd/ldykTfpmv///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink2&amp;r=5&amp;i=nad-a001-01-000000080624807&amp;d=&#39;+urlencode(&#39;http://WWW.e-HIMART.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">스마트퀵</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=MI69RAGOv+Xq7QywUjXO5v///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink3&amp;r=5&amp;i=nad-a001-01-000000080624807&amp;d=&#39;+urlencode(&#39;http://WWW.e-HIMART.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">홈스타일링</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=HlbXHNV0D2DBBwEGCJUhm////w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink4&amp;r=5&amp;i=nad-a001-01-000000080624807&amp;d=&#39;+urlencode(&#39;http://WWW.e-HIMART.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">쿠폰/출첵</a>
#                 </li>
#
#             </ul>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               한 해 가장 사랑받은 상품들을 최저가로! 카드사 최대 10%할인, 스페셜쿠폰 4종
#
#             </p></div>
#
#
#
#           </div>
#         </li>
#         <li class="lst lst6      "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="5">
#           <div class="line"></div>
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=dCsy3B2TWWitE3WioIwUzP///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_tit"
#                onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000078974043&amp;d=&#39; + urlencode(&#39;http://www.gmarket.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">G마켓 에어컨</a>
#
#
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=dCsy3B2TWWitE3WioIwUzP///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000078974043&amp;d=&#39;+urlencode(&#39;http://www.gmarket.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.gmarket.co.kr</a>
#
#             </div>
#
#
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               G마켓 잘됨 파티에는 누구나 10% 할인쿠폰+2019 첫구매라면 30% 쿠폰혜택!
#
#             </p></div>
#
#
#
#           </div>
#         </li>
#         <li class="lst lst7      "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="6">
#
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=Pf+j095HPSNJh+JOyD42Af///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_tit"
#                onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=7&amp;i=nad-a001-01-000000063827858&amp;d=&#39; + urlencode(&#39;http://www.cjmall.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">CJmall 에어컨</a>
#
#
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=Pf+j095HPSNJh+JOyD42Af///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000063827858&amp;d=&#39;+urlencode(&#39;http://www.cjmall.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.cjmall.com</a>
#               <span class="ico_area">
#                 <span class="ico">
#                   <span class="sp_ad ico_npay" alt="네이버페이" tabindex="0"
#                         onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                         onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);"
#                         onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                         onBlur="NAVER.SEARCH_AD.hideTooltip(this);">네이버페이</span>
#                   <a href="//pay.naver.com/about?frm=sa" target="_blank" class="ly_ad _tooltip"
#                      style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                      onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                      onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                      onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=pwl_nop.checkout&amp;r=7&amp;i=nad-a001-01-000000063827858&amp;u=&#39;+urlencode(this.href));">
#                     <span class="ly_box">
#                       <p>네이버 아이디 하나로 간편구매</p>
#                       <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span
#                               class="sp_ad bu"></span></p>
#                     </span>
#                       <span class="sp_ad ly_tail"></span>
#                   </a>
#                 </span>
#
#
#
#               </span>
#             </div>
#
#
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               TV쇼핑 <strong class='hl'>에어컨</strong>, 가전은 믿을 수 있는 CJ몰에서! 풍성한 방송구성 그대로!
#
#             </p></div>
#
#
#
#           </div>
#         </li>
#         <li class="lst lst8      "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="7">
#
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=7mVntf1zK2n42DiZM9cUMv///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_tit"
#                onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=8&amp;i=nad-a001-01-000000047545960&amp;d=&#39; + urlencode(&#39;http://blog.naver.com/lyysun&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">강동구 송파구  에어컨 설치</a>
#
#
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=7mVntf1zK2n42DiZM9cUMv///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=8&amp;i=nad-a001-01-000000047545960&amp;d=&#39;+urlencode(&#39;http://blog.naver.com/lyysun&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">blog.naver.com/lyysun</a>
#
#             </div>
#
#
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               강동구/송파구<strong class='hl'>에어컨</strong>설치.가스충전.중고매입판매.정직한 설치.비용
#
#             </p></div>
#
#
#
#           </div>
#         </li>
#         <li class="lst lst9      "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="8">
#
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=0vTuQ7wjXnZh8VzXu9Oyev///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_tit"
#                onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=9&amp;i=nad-a001-01-000000036842654&amp;d=&#39; + urlencode(&#39;http://아크공조.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">LG 시스템 에어컨 전문업체</a>
#
#
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=0vTuQ7wjXnZh8VzXu9Oyev///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=9&amp;i=nad-a001-01-000000036842654&amp;d=&#39;+urlencode(&#39;http://아크공조.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">아크공조.kr</a>
#
#             </div>
#
#
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               LG시스템<strong class='hl'>에어컨</strong> 영업용, 사무용, 학원, 아파트  설치,판매,유지보수 전문업체
#
#             </p></div>
#
#
#
#           </div>
#         </li>
#         <li class="lst lst10      "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="9">
#
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=HNxfrwSCmxb0GsXNiu9l3v///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_tit"
#                onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=10&amp;i=nad-a001-01-000000067277178&amp;d=&#39; + urlencode(&#39;https://cafe.naver.com/kkksys&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">LG시스템에어컨 아크공조</a>
#
#
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=HNxfrwSCmxb0GsXNiu9l3v///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=10&amp;i=nad-a001-01-000000067277178&amp;d=&#39;+urlencode(&#39;https://cafe.naver.com/kkksys&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">cafe.naver.com/kkksys</a>
#
#             </div>
#
#
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               LG휘센 대형 상업용, 주거용 천장형 <strong class='hl'>에어컨</strong> 설치 전문업체
#
#             </p></div>
#
#
#
#           </div>
#         </li>
#       </ul>
#     </div>
#
#
#     <div class="section_more">
#       <a href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%97%90%EC%96%B4%EC%BB%A8&amp;referenceId=UQhGEwp0Jy0ssh0nwBdssssssvw-509831"
#          target="_blank" class="go_site" onclick="return goOtherCR(this, &#39;a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u=&#39;+urlencode(this.href));">더보기</a>
#     </div>
#   </div>
#
#
#
#   <script crossorigin="anonymous" src="https://ssl.pstatic.net/adimg3.search/adpost/js/event_tracker.js?o=search"></script>
#
# <script type="text/javascript">
#     var _elAdIndLayerPwc = null;
#     var _elAdIndLayerTimePwc;
#     var _elDscNcautionPwc = null;
#
#     function adInfoShowPwc(el) {
#         if (_elAdIndLayerPwc) {
#             adInfoHidePwc();
#             return false;
#         } else {
#             if (!_elDscNcautionPwc) {
#                 _elDscNcautionPwc = $Element(el).parent();
#             }
#             _elDscNcautionPwc._element.style.zIndex = 121;
#             _elAdIndLayerPwc = $Element(el).next();
#             _elAdIndLayerPwc.show();
#             _elAdIndLayerTimePwc = (new Date()).getTime();
#             return true;
#         }
#     }
#
#     function adInfoHidePwc() {
#         if (_elAdIndLayerPwc) {
#             if (_elDscNcautionPwc) {
#                 _elDscNcautionPwc._element.style.zIndex = 0;
#             }
#             _elAdIndLayerPwc.hide();
#             _elAdIndLayerPwc = null;
#         }
#     };
#
#     function adInfoHideClickEventHandlerPwc(e) {
#         if (_elAdIndLayerTimePwc + 200 < (new Date()).getTime()) adInfoHidePwc();
#     };
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPwc, false); /*attach(window, "click");*/
# </script>
#
#     <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/sa/power_contents/180905/css/sa_power_cnts.css">
#
#     <div class="ad_section section bg_type_v2">
#         <div class="section_head">
#             <h2>파워컨텐츠<span class="ia_beta">Beta</span></h2>
#
#             <div class="dsc_ncaution">
#                 <em>&lsquo;<strong>에어컨</strong>&rsquo;</em>
#                 관련 광고입니다.
#                 <a href="javascript:void(0);" class="ico_ad_dsc"
#                    title="이 광고가 표시된 이유" onclick="if(adInfoShowPwc(this)) goOtherCR(this, &#39;a=pwc.info&amp;r=&amp;i=&amp;u=&#39; + urlencode(this.href));">이 광고가 표시된 이유</a>
#
#                 <div class="ly_ad_dsc" style="display:none">
#                     <span class="ico_arr">&nbsp;</span>
#
#                     <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
#                     <button type="button" class="bt_ad_clse" title="안내 레이어 닫기">안내 레이어 닫기</button>
#                 </div>
#             </div>
#             <a href="http://saedu.naver.com/adbiz/searchad/powerContents.nhn"
#                class="go_register space" target="_blank" onclick="return goOtherCR(this, &#39;a=pwc.reg&amp;r=0&amp;i=pwcregistration&amp;u=&#39; + urlencode(this.href));">파워컨텐츠 등록</a>
#         </div>
#         <div class="ad_area nx_power_cnts" id="power_contents_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=9eBKDIu5P3S_RyXwkvUVsFeiNK8MZcYogOu2ug3-...">
#             <ul class="lst_type lst_type_v3">
#                 <li class="lst">
#                     <div class="ad_thumb">
#                         <a href="https://adcr.naver.com/adcr?x=SsEWlRQmvRlfnQwfF/4UYP///w==...&amp;p=img" target="_blank" onclick="return goOtherCR(this, &#39;a=pwc.img&amp;r=1&amp;i=nad-a001-03-000000073239852&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/sgsg-done&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">
#                             <img src="https://searchad-phinf.pstatic.net/MjAxOTAzMjZfMjgg/MDAxNTUzNTg4MTUyMDMw.mrOZW2GnR_YrOhkqpZ6XcbtxLZ0xjsKDkgDFLz_1MV8g.ylzi9GMBqVD8l3kjw31UbYAzN9ewcFyu_apwc0A9P2Qg.PNG/976940-bb231523-602e-4383-b6da-a3b9a3fc65c7.png?type=f80_80" alt="2019년 &lt;strong class=&#39;hl&#39;&gt;에어컨&lt;/strong&gt; TOP5!" width="80" height="80">
#                         </a>
#                     </div>
#                     <div class="inner">
#                         <a href="https://adcr.naver.com/adcr?x=SsEWlRQmvRlfnQwfF/4UYP///w==...&amp;p=tit" class="lnk_tit" target="_blank"
#                            onclick="return goOtherCR(this, &#39;a=pwc.tit&amp;r=1&amp;i=nad-a001-03-000000073239852&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/sgsg-done&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">2019년 <strong class='hl'>에어컨</strong> TOP5!</a>
#
#                         <p class="ad_date">2019.09.18.</p>
#
#                         <p class="ad_dsc">사계절 가전으로 거듭난 <strong class='hl'>에어컨</strong>! 쓱싹에서 2019년 대세 <strong class='hl'>에어컨</strong>을 알아보겠습니다. 나에게 적합한 <strong class='hl'>에어컨</strong>은 어떤 걸까요? 2019년 <strong class='hl'>에어컨</strong> 순위를 함께 봅시다!...</p>
#
#                         <p class="ad_more">
#                             <a href="https://adcr.naver.com/adcr?x=SsEWlRQmvRlfnQwfF/4UYP///w==...&amp;p=company" class="lnk_mall"
#                                target="_blank"
#                                onclick="return goOtherCR(this, &#39;a=pwc.company&amp;r=1&amp;i=nad-a001-03-000000073239852&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/sgsg-done&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">쓱싹</a>
#                             <a href="https://adcr.naver.com/adcr?x=SsEWlRQmvRlfnQwfF/4UYP///w==...&amp;p=url" class="lnk_url"
#                                target="_blank"
#                                onclick="return goOtherCR(this, &#39;a=pwc.url&amp;r=1&amp;i=nad-a001-03-000000073239852&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/sgsg-done&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">https://blog.naver.com/sgsg-done</a>
#                         </p>
#                     </div>
#                 </li>
#                 <li class="lst">
#                     <div class="ad_thumb">
#                         <a href="https://adcr.naver.com/adcr?x=2MVLaTsyiJRS52G9+VHKtf///w==...&amp;p=img" target="_blank" onclick="return goOtherCR(this, &#39;a=pwc.img&amp;r=2&amp;i=nad-a001-03-000000075211605&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/klaircon&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">
#                             <img src="https://searchad-phinf.pstatic.net/MjAxOTEwMTFfMTU5/MDAxNTcwNzgxNDcxNDgx.MNxsYrOAkFiz44BcYrVgzhMhzb4owDZOp1saXjF5QNEg.MwH0X2camvvpo7yyhJw1-FBUjMB7yF4VCQnaoawMaAAg.PNG/595671-f9926057-2a83-4be7-921f-4f24e842a237.png?type=f80_80" alt="시스템 &lt;strong class=&#39;hl&#39;&gt;에어컨&lt;/strong&gt;요즘 대세는 왜천장형&lt;strong class=&#39;hl&#39;&gt;에어컨&lt;/strong&gt;일까?" width="80" height="80">
#                         </a>
#                     </div>
#                     <div class="inner">
#                         <a href="https://adcr.naver.com/adcr?x=2MVLaTsyiJRS52G9+VHKtf///w==...&amp;p=tit" class="lnk_tit" target="_blank"
#                            onclick="return goOtherCR(this, &#39;a=pwc.tit&amp;r=2&amp;i=nad-a001-03-000000075211605&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/klaircon&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">시스템 <strong class='hl'>에어컨</strong>요즘 대세는 왜천장형<strong class='hl'>에어컨</strong>일까?</a>
#
#                         <p class="ad_date">2019.10.08.</p>
#
#                         <p class="ad_dsc">시스템<strong class='hl'>에어컨</strong>이란 소비자의 기호, 공간의 활용, 공기조화, 등등 소비자의 편의성, 제품의 성능을 최대로 끌어낼 수 있는 설계/시공방법인데요. 절대 시스템<strong class='hl'>에어컨</strong>은 제품의 이름이 아닙니다...</p>
#
#                         <p class="ad_more">
#                             <a href="https://adcr.naver.com/adcr?x=2MVLaTsyiJRS52G9+VHKtf///w==...&amp;p=company" class="lnk_mall"
#                                target="_blank"
#                                onclick="return goOtherCR(this, &#39;a=pwc.company&amp;r=2&amp;i=nad-a001-03-000000075211605&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/klaircon&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">주식회사케이엘공조</a>
#                             <a href="https://adcr.naver.com/adcr?x=2MVLaTsyiJRS52G9+VHKtf///w==...&amp;p=url" class="lnk_url"
#                                target="_blank"
#                                onclick="return goOtherCR(this, &#39;a=pwc.url&amp;r=2&amp;i=nad-a001-03-000000075211605&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/klaircon&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">https://blog.naver.com/klaircon</a>
#                         </p>
#                     </div>
#                 </li>
#                 <li class="lst">
#                     <div class="ad_thumb">
#                         <a href="https://adcr.naver.com/adcr?x=EBJoCme6afjoWRnPEKbyif///w==...&amp;p=img" target="_blank" onclick="return goOtherCR(this, &#39;a=pwc.img&amp;r=3&amp;i=nad-a001-03-000000076293079&amp;d=&#39; + urlencode(&#39;http://blog.naver.com/rentaltok&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">
#                             <img src="https://searchad-phinf.pstatic.net/MjAxOTEwMjVfMjI2/MDAxNTcxOTc2MTcwMzMx.-ew_ACHoXwYhMsGrKl-BscvfEduH_0Ux7fm9Bqc67ysg.ZkmNUHcOq0dOWPoslSO327j69zABz5ortViV-IgtsdEg.PNG/1706239-119f334c-6d19-4f80-96be-1925e2c36b8c.png?type=f80_80" alt="모든 종류의 &lt;strong class=&#39;hl&#39;&gt;에어컨&lt;/strong&gt;&amp;냉난방기 렌탈, 한눈에 비교방법" width="80" height="80">
#                         </a>
#                     </div>
#                     <div class="inner">
#                         <a href="https://adcr.naver.com/adcr?x=EBJoCme6afjoWRnPEKbyif///w==...&amp;p=tit" class="lnk_tit" target="_blank"
#                            onclick="return goOtherCR(this, &#39;a=pwc.tit&amp;r=3&amp;i=nad-a001-03-000000076293079&amp;d=&#39; + urlencode(&#39;http://blog.naver.com/rentaltok&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">모든 종류의 <strong class='hl'>에어컨</strong>&냉난방기 렌탈, 한눈에 비교방법</a>
#
#                         <p class="ad_date">2019.10.25.</p>
#
#                         <p class="ad_dsc">수많은 렌탈업체와 제품, 브랜드 중 어느것을 선택해야 할지 모를 때 렌탈톡에서 한번에 비교&검색 해보세요.! 벽걸이, 스탠드, 2in1, 천장형 <strong class='hl'>에어컨</strong>&냉난방기 다양한 조건으로 비교할 수 있습니다....</p>
#
#                         <p class="ad_more">
#                             <a href="https://adcr.naver.com/adcr?x=EBJoCme6afjoWRnPEKbyif///w==...&amp;p=company" class="lnk_mall"
#                                target="_blank"
#                                onclick="return goOtherCR(this, &#39;a=pwc.company&amp;r=3&amp;i=nad-a001-03-000000076293079&amp;d=&#39; + urlencode(&#39;http://blog.naver.com/rentaltok&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">렌탈톡</a>
#                             <a href="https://adcr.naver.com/adcr?x=EBJoCme6afjoWRnPEKbyif///w==...&amp;p=url" class="lnk_url"
#                                target="_blank"
#                                onclick="return goOtherCR(this, &#39;a=pwc.url&amp;r=3&amp;i=nad-a001-03-000000076293079&amp;d=&#39; + urlencode(&#39;http://blog.naver.com/rentaltok&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">http://blog.naver.com/rentaltok</a>
#                         </p>
#                     </div>
#                 </li>
#             </ul>
#         </div>
#
# ...
#                      onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=biz_nop.talktalk&amp;r=2&amp;i=nad-a001-01-000000026945550&amp;u=&#39;+urlencode(this.href));">
#                     <span class="ly_box">
#                       <p>네이버톡톡으로 상담이 가능한 사이트입니다.</p>
#                       <p class="ly_ad_go"><strong>톡톡</strong> 서비스 보기<span
#                               class="sp_ad bu"></span></p>
#                     </span>
#                       <span class="sp_ad ly_tail"></span>
#                   </a>
#                 </span>
#
#               </span>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               30년 전통 케리어<strong class='hl'>에어컨</strong> 도매소매 전문점,캐리어 공식인증전문점.세금계산서,카드환영
#
#             </p></div>
#
#           </div>
#         </li>
#         <li class="lst lst3"
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="2">
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=b/aC2SWZ1wYpToN+C2yjsv///w==...&amp;p=0" target="_blank"
#                class="lnk_tit" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=3&amp;i=nad-a001-01-000000069005417&amp;d=&#39; + urlencode(&#39;https://www.myomee.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">롯데 묘미 에어컨</a>
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=b/aC2SWZ1wYpToN+C2yjsv///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=3&amp;i=nad-a001-01-000000069005417&amp;d=&#39;+urlencode(&#39;https://www.myomee.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.myomee.com</a>
#               <span class="ico_area">
#
#                 <span class="ico">
#                   <span class="sp_ad ico_nlogin"
#                         onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                         onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);"
#                         onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                         onBlur="NAVER.SEARCH_AD.hideTooltip(this);">네이버 로그인</span>
#                   <a href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn"
#                      class="ly_ad _tooltip"
#                      style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                      onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                      onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                      onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=biz_nop.naverlogin&amp;r=3&amp;i=nad-a001-01-000000069005417&amp;u=&#39;+urlencode(this.href));">
#                     <span class="ly_box">
#                       <p>네이버 아이디로 로그인이 가능합니다.</p>
#                       <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
#                     </span>
#                       <span class="sp_ad ly_tail"></span>
#                   </a>
#                 </span>
#
#
#               </span>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               최저가 혜택 삼성무풍<strong class='hl'>에어컨</strong> 월2만원대! 최대36개월할부, 첫달분납금무료!
#
#             </p></div>
#
#           </div>
#         </li>
#         <li class="lst lst4"
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="3">
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=xFeug0LqCxNvUqpzQPbo7////w==...&amp;p=0" target="_blank"
#                class="lnk_tit" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=4&amp;i=nad-a001-01-000000080508867&amp;d=&#39; + urlencode(&#39;http://housingrnetal.co.kr/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">종합가전렌탈몰 하우징렌탈몰</a>
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=xFeug0LqCxNvUqpzQPbo7////w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=4&amp;i=nad-a001-01-000000080508867&amp;d=&#39;+urlencode(&#39;http://housingrnetal.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">housingrnetal.co.kr/</a>
#
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               선납금 0원 모든 가전제품 신속한 무료배송설치완료, 36개월 후 본인소유권이전
#
#             </p></div>
#
#           </div>
#         </li>
#         <li class="lst lst5"
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="4">
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=a5PgUiI9pAWlggZhMMXUPv///w==...&amp;p=0" target="_blank"
#                class="lnk_tit" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=5&amp;i=nad-a001-01-000000009996984&amp;d=&#39; + urlencode(&#39;http://www.danawa.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">에어컨 다나와</a>
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=a5PgUiI9pAWlggZhMMXUPv///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000009996984&amp;d=&#39;+urlencode(&#39;http://www.danawa.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.danawa.com</a>
#               <span class="ico_area">
#
#                 <span class="ico">
#                   <span class="sp_ad ico_nlogin"
#                         onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                         onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);"
#                         onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                         onBlur="NAVER.SEARCH_AD.hideTooltip(this);">네이버 로그인</span>
#                   <a href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn"
#                      class="ly_ad _tooltip"
#                      style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                      onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                      onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                      onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=biz_nop.naverlogin&amp;r=5&amp;i=nad-a001-01-000000009996984&amp;u=&#39;+urlencode(this.href));">
#                     <span class="ly_box">
#                       <p>네이버 아이디로 로그인이 가능합니다.</p>
#                       <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
#                     </span>
#                       <span class="sp_ad ly_tail"></span>
#                   </a>
#                 </span>
#
#
#               </span>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               <strong class='hl'>에어컨</strong>, 살 땐 사더라도 최저가로 알뜰쇼핑 하셔야죠! 가격비교 다나와!
#
#             </p></div>
#
#           </div>
#         </li>
#       </ul>
#     </div>
#
#     <div class="ad_banner">
#       <span class="sp_ad ico_npay">네이버페이</span>네이버페이로 결제하고 포인트 혜택 받으세요
#       <a href="https://event2.pay.naver.com/event/benefit/list" target="_blank"
#          onclick="return goOtherCR(this, 'a=mib_biz.banner&r=0&i=mib_bizbanner&u='+urlencode(this.href));"
#          class="more_mileage">자세히 보기</a>
#     </div>
#     <div class="section_more">
#       <a href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%97%90%EC%96%B4%EC%BB%A8&amp;referenceId=UQhGEwp0Jy0ssh0nwBdssssssvw-509831"
#          target="_blank" class="go_site" onclick="return goOtherCR(this, &#39;a=biz_nop.more&amp;r=1&amp;i=bizmore&amp;u=&#39;+urlencode(this.href));">더보기</a>
#     </div>
#   </div>
#
#   <script type="text/javascript"> var b_show_lang_list=false; function ldcprs_play_sound(el, url) { obj = nhn.common.audio_player; obj.stop(); obj.setEffect(el, 'playing', 'loading'); obj.play(url); } function toggle_lang_list_ldcprs() { if(b_show_lang_list==false) { show_toggle_lang_list(true, true); } else { show_toggle_lang_list(false, true); } } function show_toggle_lang_list(b_show, b_click_log) { var btn_id = "btn_toggle_lang_list"; var area_id = "area_toggle_lang_list"; var elem_btn = document.getElementById(btn_id); var elem_area = document.getElementById(area_id); if (elem_btn==null || elem_area==null) return; var class_name = elem_btn.className; if (b_show) { /*close->open*/ elem_area.className = "dic_dsc"; elem_btn.innerHTML = "접기"; /*-------------------------------------------------- * area = "caf.unfd"; / *fixme* / *--------------------------------------------------*/ } else { elem_area.className = "dic_dsc closed"; elem_btn.innerHTML = "펼치기"; /*-------------------------------------------------- * area = "caf.fold"; / *fixme* / *--------------------------------------------------*/ } if (b_click_log) { /*-------------------------------------------------- * tCR("a="+area+"&r=0&i=&u=javascript"); *--------------------------------------------------*/ } b_show_lang_list = b_show; } function wiki_escape(url) { if(navigator.appName.charAt(0) == "M" && navigator.appVersion.indexOf("MSIE 6") != -1) { tmp = escape(url); ret = tmp.replace("http\%3A", "http:"); } else { if (navigator.appName.indexOf("Opera") != -1) { len = url.length; last_pos = url.lastIndexOf("/"); url_prefix = url.substr(0, last_pos + 1); url_item = url.substr(last_pos + 1, len - last_pos); ret = url_prefix + (encodeURIComponent(url_item)); } else ret = url; } return ret; } function toggle_popup_layer_ldc_prs(id_el) { var el = document.getElementById(id_el); if(el) { if (el.style.display === 'none') { el.style.display = 'block'; } else { el.style.display = 'none'; } } } </script> <script type="text/javascript" src="https://ssl.pstatic.net/sstatic/search/ldic/js/ToggleLayerControl_110411a.js"></script> <script type="text/javascript"> var oLdicprsToggleLayer = new nhn.ToggleLayerControl({ sToggleClassName : '_toggle' }); </script> <div class="ndic section" id="id_ldic_nx_section_layer"> <div class="section_head"> <h2>어학사전</h2> </div> <ul class="dic"> <li class="dic_kr dic_aside"> <dl> <dt>국어사전</dt> <dd class="dic_dsc "> <dl > <dt ><a class="" target="_blank" href="https://ko.dict.naver.com/#/entry/koko/7248ed5785e742b6978cf261e549aa8c" onclick="return goOtherCR(this,'a=ldc_btm*k.entry&r=1&i=8800000f_7248ed5785e742b6978cf261e549aa8c&u='+urlencode(this.href));"><strong class="hl">에어컨</strong></a></dt> <dd class="txt_inline"> <span class="txt_exp">(air conditioner)</span> <a href="#" onclick="ldcprs_play_sound(this,'https://dict-dn.pstatic.net/naver/dic/naverdic/krdic/sound/words/000/000789.mp3?_lsu_sa_=31285f558df535a69b9dd12b3ec420f98d8564952d089f6164029f75cb446b71535f17576e058478d9196b154b2b305bb2014e62d8b5cc4beac0efe9c120c2ca20059aa98d8b56e6835d709ffa43d5cb'); tCR('a=ldc_btm*k.sound&r=1&i=8800000f_7248ed5785e742b6978cf261e549aa8c', this); return false;" class="play"><img src="https://ssl.pstatic.net/sstatic/search/dic/loading_s.gif" width="16" height="4" alt="로딩중" class="ico_loading"><i class="sprenew api_ico_listen">발음듣기</i></a> <span class='dic_grade'><span style='width:30px;'><em class='blind'>중요도 별점 3개</em></span></span> <span class="txt_other"><a href="http://krdic.naver.com/search.nhn?kind=study&query=%EC%97%90%EC%96%B4%EC%BB%A8" target="_blank" onclick="return goOtherCR(this,'a=ldc_btm*k.study&r=1&i=8800000f_7248ed5785e742b6978cf261e549aa8c&u='+urlencode(this.href));">맞춤법·표기법</a></span> </dd> <dd>[명사] 여름에 실내 공기의 온도, 습도를 조절하는 장치. </dd> </dl> </dd> </dl> </li> <li class="dic_en dic_aside"> <dl> <dt>영어사전</dt> <dd class="dic_dsc "> <dl > <dt ><a class="" target="_blank" href="http://endic.naver.com/krenEntry.nhn?entryId=d8d0a105d83f40018ea6d9b47d1ca07c"  ...
# <div class='result_more section' id='nx_result_more'> <div class='section_head'> <h2>검색결과 더보기</h2> </div> <div class='rsltmr_area'> <ul> <li><a onclick="return goOtherCR(this, 'a=blg_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='?query=%EC%97%90%EC%96%B4%EC%BB%A8&where=post&sm=tab_mre&nso='><strong>블로그</strong><span class='more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=vdo_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='?where=video&ie=utf8&nso=&sm=tab_mre&query=%EC%97%90%EC%96%B4%EC%BB%A8'><strong>동영상</strong><span class='more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=kin_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='https://search.naver.com/search.naver?where=kin&query=%EC%97%90%EC%96%B4%EC%BB%A8&nso=so:r,a:all,p:all&sm=tab_mre'><strong>지식iN</strong><span class='more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=img_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='?where=image&query=%EC%97%90%EC%96%B4%EC%BB%A8&nso=so%3Ar%2Ca%3Aall%2Cp%3Aall&sm=tab_mre'><strong>이미지</strong><span class='more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=caf_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='?where=article&query=%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&sm=tab_mre'><strong>카페</strong><span class='more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=nws_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='?&where=news&query=%EC%97%90%EC%96%B4%EC%BB%A8&sm=tab_mre&frm=mr&nso=so:r,p:all,a:all&sort=0'><strong>뉴스</strong><span class='more'></span></a></li><li><a target=_blank onclick="return goOtherCR(this, 'a=app_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='https://s.search.naver.com/p/mobileapp/search.naver?where=svc&query=%EC%97%90%EC%96%B4%EC%BB%A8'><strong>앱정보</strong><span class='site_more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=rea_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='?where=realtime&sm=tab_mre&query=%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8'><strong>실시간검색</strong><span class='more'></span></a></li> <li><div><span></span></div></li> <li><div><span></span></div></li> <li><div><span></span></div></li> <li><div><span></span></div></li> </ul> </div> </div> <script> nhn = window.nhn || {}; nhn.search = nhn.search || {}; nhn.search.ResultTabToggler = jindo.$Class({ _welWrapper: null, _welUl: null, _nLength: 0, _nWidth: 0, _nItemHeight: 0, _htConfig: {}, $init: function(b) { this._htConfig = this._validate(b); if (!$(this._htConfig.sId)) { return false; } this._welWrapper = jindo.$Element(this._htConfig.sId); this._welUl = jindo.$Element($$.getSingle("ul", this._welWrapper._element)); var a = $$("a", this._welWrapper._element); this._nLength = a.length; this._nItemHeight = jindo.$Element(a[0]).parent().height(); this._switchClass(); this._attachEvent(); }, _validate: function(b) { var c = { nMaxWidth: 795 }; for (var a in b) { if (b[a]) { c[a] = b[a]; } } return c; }, _attachEvent: function() { jindo.$Fn(this._switchClass, this).attach(window, "resize"); }, _getRow: function(c, a) { var b = 1; if (c % a > 0) { b = Math.ceil(c / a); } else { b = c / a; } return b; }, _switchClass: function() { var b = 4, c = 0, a = this._welWrapper.width(); if (a >= this._htConfig.nMaxWidth) { b = 5; this._welWrapper.addClass("result_more2"); } else { this._welWrapper.removeClass("result_more2"); } c = this._getRow(this._nLength, b); this._welUl.css("height", c * this._nItemHeight + "px"); } }); </script> <script type="text/javascript"> (function() { new nhn.search.ResultTabToggler({ sId : 'nx_result_more' }); }()); </script><link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/20 ...
