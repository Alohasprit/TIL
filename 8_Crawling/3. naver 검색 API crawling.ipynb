# %%
import urllib.request
import bs4
import os
import sys

# %%
client_id = "20uqHAr39TBYdOu4URT"
client_secret = "lI2Bsf3dps"
encText = urllib.parse.quote("로밍")
url ="https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EC%97%90%EC%96%B4%EC%BB%A8"

# %%
request = urllib.request.Request(url)

# %%
request.add_header("X-Naver.Client-Id", client_id)
request.add_header("X-Naver.Client-Secret", client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

# %%
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="에어컨 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'에어컨'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'에어컨'의 네이버 통합검색 결과입니다."> <title>에어컨 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_140327.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_190221.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_190221.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/api_atcmp_181122.css"><script type="text/javascript"> naver = window.naver || {}; naver.search = naver.search || {}; var g_D = 0 ; if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } function urlencode (q) { return escape(q).replace(/\+/g, "%2B") ; } function urlexpand (url) { var href = document.location.href ; if (url == "") return href ; if (url.match(/^[-.A-Za-z]+:/)) return url ; if (url.charAt(0) == '#') return href.split("#")[0] + url ; if (url.charAt(0) == '?') return href.split("?")[0] + url ; if (url.charAt(0) == '/') return href.replace(/([^:\/])\/.*$/, "$1") + url ; return href.substring(0, href.lastIndexOf("/")+1) + url ; } naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + "; expires=" + exdate.toUTCString(); } } cookie = cookie + "; path=/"; if (domain != null) { cookie = cookie + "; domain=" + domain; } document.cookie = cookie; }, get : function (key) { var cookie_list = document.cookie.split(/\s*;\s*/); for (var i = 0; i < cookie_list.length; i++) { var tmp_list = cookie_list[i].split("="); var c_key = tmp_list[0].trim(); var c_value = tmp_list[1]; if (key == c_key) { return unescape(c_value); } } return null; } } })(); naver.search.https = window.location.protocol == "https:"; naver.search.meta_referrer = 0; var _nx_js_load = (function () { var scrs = {} ; return function (script, callback) { scrs[script] = {} ; scrs[script].domscript = document.createElement('script'); scrs[script].domscript.src = script ; if (callback) scrs[script].callback = (callback instanceof Array) ? callback : [callback]; scrs[script].domscript.onloadDone = false; scrs[script].domscript.onload = function() { scrs[script].domscript.onloadDone = true; if (scrs[script].callback) { for (var i = 0; i < scrs[script].callback.length; i++) { scrs[script].callback[i]() ; } } scrs[script].domscript.onload = scrs[script].domscript.onreadystatechange = null; } ; scrs[script].domscript.onreadystatechange = function() { if ( ("loaded" === scrs[script].domscript.readyState || "complete" === scrs[script].domscript.readyState) && !scrs[script].domscript.onloadDone ) { scrs[script].domscript.onload(); } } ; document.getElementsByTagName('head')[0].append ...
#
# <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#         NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#         NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#         var parentElement = $Element(element).parent();
#         var timerAttribute = parentElement.attr("data-timer");
#         if (timerAttribute) {
#             clearTimeout(timerAttribute);
#             parentElement.attr("data-timer", "");
#         }
#         var tooltipElement = $Element(parentElement.query("._tooltip"));
#         tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#         var parentElement = $Element(element).parent();
#         if (!parentElement.attr("data-timer")) {
#             var timer = setTimeout(function () {
#                 var tooltipElement = $Element(parentElement.query("._tooltip"));
#                 tooltipElement.css("display", "none");
#             }, 100);
#             parentElement.attr("data-timer", timer);
#         }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#         if (_elAdIndLayerPl) {
#             adInfoHidePl();
#             return false;
#         } else {
#             if (!_elDscNcautionPl) {
#                 _elDscNcautionPl = $Element(el).parent();
#             }
#             _elDscNcautionPl._element.style.zIndex = 121;
#             _elAdIndLayerPl = $Element(el).next();
#             _elAdIndLayerPl.show();
#             _elAdIndLayerTimePl = (new Date()).getTime();
#             return true;
#         }
#     }
#
#     function adInfoHidePl() {
#         if (_elAdIndLayerPl) {
#             if (_elDscNcautionPl) {
#                 _elDscNcautionPl._element.style.zIndex = 0;
#             }
#             _elAdIndLayerPl.hide();
#             _elAdIndLayerPl = null;
#         }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#         if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
# </script>
# <link href="https://ssl.pstatic.net/sstatic/search/sa/180906/css/sa.css" rel="stylesheet" type="text/css" />
# <link href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css" rel="stylesheet" type="text/css" />
# <div class="ad_section section _pl_section bg_type_v2">
#     <div class="section_head"><h2>파워링크</h2>
#
#         <div class="dsc_ncaution">
#           <span><em class="dsc_ncaution_quotation">&lsquo;</em><strong class="dsc_ncaution_keyword">에어컨</strong><em class="dsc_ncaution_quotation">&rsquo;</em></span>
#           <span class="dsc_ncaution_text">관련 광고입니다.</span>
#           <a class="ico_ad_dsc" href="javascript:void(0);" title="이 광고가 표시된 이유" onclick="if(adInfoShowPl(this)) goOtherCR(this, &#39;a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u=&#39;+urlencode(this.href));">이 광고가 표시된 이유</a>
#
#           <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none"><span class="ico_arr">&nbsp;</span>
#
#               <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
#               <button class="bt_ad_clse" title="안내 레이어 닫기" type="button">안내 레이어 닫기</button>
#           </div>
#         </div>
#         <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u=&#39;+urlencode(this.href));">등록 안내</a>
#     </div>
#     <div class="ad_area nx_power" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=o-bAoxEkvZHjSKqvaz29Ip09JLHSgLsJKmXWT-...">
#         <ul class="lst_type">
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="0" class="lst lst1">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=TRZH+Mzne+aTTkEKcdmk0P///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000056243732&amp;d=&#39; + urlencode(&#39;http://www.systemairlg.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">MS시스템에어컨 전문설치기업</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=TRZH+Mzne+aTTkEKcdmk0P///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000056243732&amp;d=&#39;+urlencode(&#39;http://www.systemairlg.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.systemairlg.co.kr</a>
#
#                     <p class="ad_dsc">
#                       LG시스템<strong class='hl'>에어컨</strong> 설계 판매 매입 시공 유지보수전문점 무상A/S 2년
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="1" class="lst lst2">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=BBozA8VVOARw2NzlzPaRZ////w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000034888825&amp;d=&#39; + urlencode(&#39;http://www.dayou-winia.com/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">대유위니아 에어컨</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=BBozA8VVOARw2NzlzPaRZ////w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000034888825&amp;d=&#39;+urlencode(&#39;http://www.dayou-winia.com/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.dayou-winia.com/</a>
#
#                     <p class="ad_dsc">
#                       바람의 방향을 바꿔 춥지않고 시원한 둘레바람, 민감한 아기를 위한 아기모드까지!
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="2" class="lst lst3">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=x/AQLhhhchnCd2z418jF3P///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000005784411&amp;d=&#39; + urlencode(&#39;http://www.centuryshop.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">(주)에프씨센추리 직영몰</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=x/AQLhhhchnCd2z418jF3P///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000005784411&amp;d=&#39;+urlencode(&#39;http://www.centuryshop.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.centuryshop.kr</a>
#
#                     <p class="ad_dsc">
#                       센추리<strong class='hl'>에어컨</strong>, 산업, 업소용<strong class='hl'>에어컨</strong>, 냉난방기전문기업, 센추리SHOP.
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="3" class="lst lst4">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=2NeStE1sG7IWvsrFSpnxGf///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000030606496&amp;d=&#39; + urlencode(&#39;http://whisen.lge.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">LG 휘센 씽큐</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=2NeStE1sG7IWvsrFSpnxGf///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000030606496&amp;d=&#39;+urlencode(&#39;http://whisen.lge.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">whisen.lge.co.kr</a>
#
#                     <p class="ad_dsc">
#                       365일 인공지능 씽큐로 공간학습 상황학습 사용패턴학습. 인공지능 스스로 <strong class='hl'>에어컨</strong>.
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="4" class="lst lst5">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=n+gvD1IKJa/HHs+iiH6QHv///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=5&amp;i=nad-a001-01-000000006501357&amp;d=&#39; + urlencode(&#39;http://lgsac.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">LG휘센 시스템에어컨특판</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=n+gvD1IKJa/HHs+iiH6QHv///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000006501357&amp;d=&#39;+urlencode(&#39;http://lgsac.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">lgsac.co.kr</a>
#
#                     <p class="ad_dsc">
#                       LG시스템<strong class='hl'>에어컨</strong> 판매 학원 병원 종교시설 사무실 상가 현장방문 견적.
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="5" class="lst lst6">
#                 <div class="line"></div>
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=wreiFNL7PQyDfljjw9ZqgP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000036168794&amp;d=&#39; + urlencode(&#39;http://www.cjhello.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">CJ 헬로 공식 렌탈샵</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=wreiFNL7PQyDfljjw9ZqgP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000036168794&amp;d=&#39;+urlencode(&#39;http://www.cjhello.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.cjhello.com</a>
#
#                     <p class="ad_dsc">
#                       <strong class='hl'>에어컨</strong>, 월 20,800원으로 부담없이 사용하자! A/S 3년 보장은 기본!
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="6" class="lst lst7">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=5iQSIu+bK/AMbKPXJxGjiP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=7&amp;i=nad-a001-01-000000056981527&amp;d=&#39; + urlencode(&#39;https://smartstore.naver.com/thebestlg&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">LG 에어컨 공식판매점 지성</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=5iQSIu+bK/AMbKPXJxGjiP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000056981527&amp;d=&#39;+urlencode(&#39;https://smartstore.naver.com/thebestlg&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">smartstore.naver.com/thebestlg</a>
#           <span class="ico_area">
#             <span class="ico">
#               <span alt="네이버페이" class="sp_ad ico_npay" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
#               <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.checkout&amp;r=7&amp;i=nad-a001-01-000000056981527&amp;u=&#39;+urlencode(this.href));">
#                 <span class="ly_box">
#                   <p>네이버 아이디 하나로 간편구매</p>
#                   <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
#                 </span>
#                   <span class="sp_ad ly_tail"></span>
#               </a>
#             </span>
#
#
#
#           </span>
#                     <p class="ad_dsc">
#                       LG 휘센 <strong class='hl'>에어컨</strong> 톡톡친구/스토어찜 쿠폰할인 및 베스트리뷰선정시 N페이 2만지급
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="7" class="lst lst8">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=Fd8m6oLNP9AkEdf6KsyNVP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=8&amp;i=nad-a001-01-000000052934273&amp;d=&#39; + urlencode(&#39;http://www.sinwoo303.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">삼성LG케리어에어컨전문점</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=Fd8m6oLNP9AkEdf6KsyNVP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=8&amp;i=nad-a001-01-000000052934273&amp;d=&#39;+urlencode(&#39;http://www.sinwoo303.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.sinwoo303.com</a>
#
#                     <p class="ad_dsc">
#                       B2B 삼성시스템<strong class='hl'>에어컨</strong>설치전문점, 초특판가 판매 서울전지역 실사 및 책임시공
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="8" class="lst lst9">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=HQ7QUP0SOmIWi6YiO5d5MP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=9&amp;i=nad-a001-01-000000057172446&amp;d=&#39; + urlencode(&#39;http://www.coupang.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">에어컨 쿠팡</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=HQ7QUP0SOmIWi6YiO5d5MP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=9&amp;i=nad-a001-01-000000057172446&amp;d=&#39;+urlencode(&#39;http://www.coupang.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.coupang.com</a>
#
#                     <p class="ad_dsc">
#                       <strong class='hl'>에어컨</strong> 특가! 냉방가전, 벽걸이형<strong class='hl'>에어컨</strong>, 똑똑한 선택, 가전제품은 쿠팡.
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="9" class="lst lst10">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=ZJy1SqfWG/VWb799M7o9WP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=10&amp;i=nad-a001-01-000000025459642&amp;d=&#39; + urlencode(&#39;http://aircon24.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">천정형에어컨 중앙시스템에어컨</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=ZJy1SqfWG/VWb799M7o9WP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=10&amp;i=nad-a001-01-000000025459642&amp;d=&#39;+urlencode(&#39;http://aircon24.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">aircon24.kr</a>
#
#                     <p class="ad_dsc">
#                       <strong class='hl'>에어컨</strong>, 1등급시스템<strong class='hl'>에어컨</strong>, 1등급냉난방기 판매시공, 서울경기수도권 환영
#
#                     </p>
#
#                 </div>
#             </li>
#         </ul>
#     </div>
#
#
#     <div class="section_more">
#         <a class="go_site" target="_blank" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%97%90%EC%96%B4%EC%BB%A8&amp;referenceId=U5l0ilpySDlssaCo1%2FRssssstdo-403283&amp;bucket=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u=&#39;+urlencode(this.href));">더보기</a>
#     </div>
# </div><script crossorigin="anonymous" src="https://ssl.pstatic.net/adimg3.search/adpost/js/event_tracker.js?o=search"></script>
#
# <script type="text/javascript">
#     var _elAdIndLayerPwc = null;
#     var _elAdIndLayerTimePwc;
#     var _elDscNcautionPwc = null;
#
#     function adInfoShowPwc(el) {
#         if (_elAdIndLayerPwc) {
#             adInfoHidePwc();
#             return false;
#         } else {
#             if (!_elDscNcautionPwc) {
#                 _elDscNcautionPwc = $Element(el).parent();
#             }
#             _elDscNcautionPwc._element.style.zIndex = 121;
#             _elAdIndLayerPwc = $Element(el).next();
#             _elAdIndLayerPwc.show();
#             _elAdIndLayerTimePwc = (new Date()).getTime();
#             return true;
#         }
#     }
#
#     function adInfoHidePwc() {
#         if (_elAdIndLayerPwc) {
#             if (_elDscNcautionPwc) {
#                 _elDscNcautionPwc._element.style.zIndex = 0;
#             }
#             _elAdIndLayerPwc.hide();
#             _elAdIndLayerPwc = null;
#         }
#     };
#
#     function adInfoHideClickEventHandlerPwc(e) {
#         if (_elAdIndLayerTimePwc + 200 < (new Date()).getTime()) adInfoHidePwc();
#     };
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPwc, false); /*attach(window, "click");*/
# </script>
#
#     <link href="https://ssl.pstatic.net/sstatic/search/sa/power_contents/180905/css/sa_power_cnts.css" rel="stylesheet" type="text/css" />
#
#     <div class="ad_section section bg_type_v2">
#         <div class="section_head">
#             <h2>파워컨텐츠<span class="ia_beta">Beta</span></h2>
#
#             <div class="dsc_ncaution">
#                 <em>&lsquo;<strong>에어컨</strong>&rsquo;</em>
#                 관련 광고입니다.
#                 <a class="ico_ad_dsc" href="javascript:void(0);" title="이 광고가 표시된 이유" onclick="if(adInfoShowPwc(this)) goOtherCR(this, &#39;a=pwc_pro.info&amp;r=&amp;i=&amp;u=&#39; + urlencode(this.href));">이 광고가 표시된 이유</a>
#
#                 <div class="ly_ad_dsc" style="display:none">
#                     <span class="ico_arr">&nbsp;</span>
#
#                     <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
#                     <button class="bt_ad_clse" title="안내 레이어 닫기" type="button">안내 레이어 닫기</button>
#                 </div>
#             </div>
#             <a class="go_register space" href="http://saedu.naver.com/adbiz/searchad/powerContents.nhn" target="_blank" onclick="return goOtherCR(this, &#39;a=pwc_pro.reg&amp;r=0&amp;i=pwc_proregistration&amp;u=&#39; + urlencode(this.href));">파워컨텐츠 등록</a>
#         </div>
#         <div class="ad_area nx_power_cnts" id="power_contents_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=...">
#             <ul class="lst_type lst_type_v3">
#                 <li class="lst">
#                     <div class="ad_thumb">
#                         <a target="_blank" href="https://adcr.naver.com/adcr?x=GAcc37P6Yw3AJoc8nwjqhv///w==...&amp;p=img" onclick="return goOtherCR(this, &#39;a=pwc_pro.img&amp;r=1&amp;i=nad-a001-03-000000055863556&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/jusamjung&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">
#                             <img height="80" width="80" alt="LG 휘센 &lt;strong class=&#39;hl&#39;&gt;에어컨&lt;/strong&gt; 미리미리 알아보고 준비하기" src="https://searchad-phinf.pstatic.net/MjAxOTAzMDdfMTMg/MDAxNTUxOTM3NDgwNjYy.w6PhHDHS-w_8eihls5gu-oOJSaMSTLJ6_nPP9tCozd0g.ZA95dIKKYaYPMJYAu0HPOVd3I1hPaAjZWUi6svwBa8Ig.PNG/708176-803336f0-4198-433e-b61c-aaf88dfbb5c9.png?type=f80_80" />
#                         </a>
#                     </div>
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=GAcc37P6Yw3AJoc8nwjqhv///w==...&amp;p=tit" onclick="return goOtherCR(this, &#39;a=pwc_pro.tit&amp;r=1&amp;i=nad-a001-03-000000055863556&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/jusamjung&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">LG 휘센 <strong class='hl'>에어컨</strong> 미리미리 알아보고 준비하기</a>
#
#                         <p class="ad_date">2019.03.07.</p>
#
#                         <p class="ad_dsc"><strong class='hl'>에어컨</strong>은 역시 LG 휘센! LG 휘센 벽걸이,스탠드<strong class='hl'>에어컨</strong> 신제품이 출시되었다. 7~8월에 <strong class='hl'>에어컨</strong> 구매를 하려고 하면 설치일정이 밀리기 쉬우니 기능, 가격 미리 비교분석하여 남들보다 빠르게 구매하자!...</p>
#
#                         <p class="ad_more">
#
#                             <a class="lnk_mall" target="_blank" href="https://adcr.naver.com/adcr?x=GAcc37P6Yw3AJoc8nwjqhv///w==...&amp;p=company" onclick="return goOtherCR(this, &#39;a=pwc_pro.company&amp;r=1&amp;i=nad-a001-03-000000055863556&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/jusamjung&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">LG 공식판매점 삼정</a>
#                             <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=GAcc37P6Yw3AJoc8nwjqhv///w==...&amp;p=url" onclick="return goOtherCR(this, &#39;a=pwc_pro.url&amp;r=1&amp;i=nad-a001-03-000000055863556&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/jusamjung&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">https://blog.naver.com/jusamjung</a>
#                         </p>
#                     </div>
#                 </li>
#                 <li class="lst">
#                     <div class="ad_thumb">
#                         <a target="_blank" href="https://adcr.naver.com/adcr?x=JJApkhfqdTWmK4ngtewSDP///w==...&amp;p=img" onclick="return goOtherCR(this, &#39;a=pwc_pro.img&amp;r=2&amp;i=nad-a001-03-000000057010865&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/teamoto&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">
#                             <img height="80" width="80" alt="삼성무풍&lt;strong class=&#39;hl&#39;&gt;에어컨&lt;/strong&gt;은 어떤기능으로 업그레이드됐을까" src="https://searchad-phinf.pstatic.net/MjAxOTAzMTlfMTU4/MDAxNTUyOTg3ODI5MjY3.iZbKysc5PdlopLFAYiewBHOXzbC_fdFI4_cUV_Wh-wYg.-eDEzNaZQaCuR2xykhmtpsItRGb6wCWom0A54SvO3NEg.PNG/1507418-b1c65825-759c-4246-95f8-79659f8daa35.png?type=f80_80" />
#                         </a>
#                     </div>
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=JJApkhfqdTWmK4ngtewSDP///w==...&amp;p=tit" onclick="return goOtherCR(this, &#39;a=pwc_pro.tit&amp;r=2&amp;i=nad-a001-03-000000057010865&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/teamoto&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">삼성무풍<strong class='hl'>에어컨</strong>은 어떤기능으로 업그레이드됐을까</a>
#
#                         <p class="ad_date">2019.03.19.</p>
#
#                         <p class="ad_dsc"><strong class='hl'>에어컨</strong>렌탈 하면 삼성무풍<strong class='hl'>에어컨</strong>으로 알아보시는 분들이 많은것 같은데 그 이유로는 시원함은 좋은데 찬바람을 싫어하는 소비자들에게 큰 인기를 얻고 있어요...</p>
#
#                         <p class="ad_more">
#
#                             <a class="lnk_mall" target="_blank" href="https://adcr.naver.com/adcr?x=JJApkhfqdTWmK4ngtewSDP///w==...&amp;p=company" onclick="return goOtherCR(this, &#39;a=pwc_pro.company&amp;r=2&amp;i=nad-a001-03-000000057010865&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/teamoto&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">오투오렌탈</a>
#                             <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=JJApkhfqdTWmK4ngtewSDP///w==...&amp;p=url" onclick="return goOtherCR(this, &#39;a=pwc_pro.url&amp;r=2&amp;i=nad-a001-03-000000057010865&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/teamoto&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">https://blog.naver.com/teamoto</a>
#                         </p>
#                     </div>
#                 </li>
#                 <li class="lst">
#                     <div class="ad_thumb">
#                         <a target="_blank" href="https://adcr.naver.com/adcr?x=b4h82EfxwfTPDmC7Esr5TP///w==...&amp;p=img" onclick="return goOtherCR(this, &#39;a=pwc_pro.img&amp;r=3&amp;i=nad-a001-03-000000055532139&amp;d=&#39; + urlencode(&#39;http://blog.naver.com/tvttvt&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">
#                             <img height="80" width="80" alt="2019 최신형 &lt;strong class=&#39;hl&#39;&gt;에어컨&lt;/strong&gt; 한번에 해부하자!" src="https://searchad-phinf.pstatic.net/MjAxOTAzMDVfMTcz/MDAxNTUxNzYxNjc2ODQ2.sFkt_UM6msrMtE7pRcfDz0tG2eYT_i7_ZRdqT69BPi4g.4K8UvC39jTTrJ_2Se2Q9ecAc4wV4_Pe0dBrvDwbPMhMg.PNG/704399-91f71f69-35d3-45bd-8371-0555a51c1a6b.png?type=f80_80" />
#                         </a>
#                     </div>
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=b4h82EfxwfTPDmC7Esr5TP///w==...&amp;p=tit" onclick="return goOtherCR(this, &#39;a=pwc_pro.tit&amp;r=3&amp;i=nad-a001-03-000000055532139&amp;d=&#39; + urlencode(&#39;http://blog.naver.com/tvttvt&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">2019 최신형 <strong class='hl'>에어컨</strong> 한번에 해부하자!</a>
#
#                         <p class="ad_date">2019.03.03.</p>
#
#                         <p class="ad_dsc">작년 여름 <strong class='hl'>에어컨</strong> 배송 대란으로 7월 부터는 설치가 정말 어려웠다. 올해는 미리 미리 준비해서 시원하고 쾌적한 여름을 보내자! 삼성, 캐리어, 위니아 등 장점 비교!...</p>
#
#                         <p class="ad_more">
#
#                             <a class="lnk_mall" target="_blank" href="https://adcr.naver.com/adcr?x=b4h82EfxwfTPDmC7Esr5TP///w==...&amp;p=company" onclick="return goOtherCR(this, &#39;a=pwc_pro.company&amp;r=3&amp;i=nad-a001-03-000000055532139&amp;d=&#39; + urlencode(&#39;http://blog.naver.com/tvttvt&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">렌탈프랜드</a>
#                             <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=b4h82EfxwfTPDmC7Esr5TP///w==...&amp;p=url" onclick="return goOtherCR(this, &#39;a=pwc_pro.url&amp;r=3&amp;i=nad-a001-03-000000055532139&amp;d=&#39; + urlencode(&#39;http://blog.naver.com/tvttvt&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">http://blog.naver.com/tvttvt</a>
#                         </p>
#                     </div>
#                 </li>
#
#             </ul>
#         </div>
#         <div class="section_more">
#             <a class="go_site" target="_blank" href="https://ad.search.naver.com/search.naver?where=pwcexpd&amp;query=%EC%97%90%EC%96%B4%EC%BB%A8&amp;referenceId=U5l0ilpySDlssaCo1%2FRssssstdo-403283" onclick="return goOtherCR(this, &#39;a=pwc_pro.more&amp;r=&amp;i=&amp;u=&#39; + urlencode(this.href));">더보기</a>
#         </div>
#     </div><script type="text/javascript"> _spt.anchor['a1'] = (new Date()).getTime() ; </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_shop_default_190131.css"> <script type="text/javascript">function shp_no_image(o, c) { o.onerror = null; o.src = 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif'; o.className = c; o.alt = '이미지 준비중';} </script> <div class="sp_shop_default section" id='_shopping_guide_view'> <div class="section_head"> <h2>네이버쇼핑</h2> <div class="dsc_ncaution2 _shopping_info_area"> <a href="#" onclick="return tCR('a=shp_gui.imark&r=&i=&u=javascript');" class="ico_ad_dsc _open_btn" title="이 정보가 표시된 이유">이 정보가 표시된 이유</a> <div class="ly_ad_dsc _layer" style="display:none;"> <span class="ico_arr">&nbsp;</span> <p>네이버가 운영하는 쇼핑 서비스입니다.</p> <button type="button" class="bt_ad_clse _close_btn" title="안내 레이어 닫기" onclick="return tCR('a=shp_gui.guideclose&r=&i=&u=javascript');">안내 레이어 닫기</button> </div> </div> <div class="dsc_ninfo">다른 사이트를 보시려면 <a href="?where=webkr&opt_src=site&sm=tab_shp&query=%EA%B0%80%EA%B2%A9%EB%B9%84%EA%B5%90%EC%82%AC%EC%9D%B4%ED%8A%B8+-%EB%84%A4%EC%9D%B4%EB%B2%84" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&r=&i=&a=shp_gui.pricesite');">여기</a>를 누르세요.</div> </div> <p class="title_desc title_desc_v2">'<em>에어컨</em>' 상품 <a href="https://search.shopping.naver.com/search/all.nhn?query=%EC%97%90%EC%96%B4%EC%BB%A8&frm=NVSCPRO" onclick="return goOtherCR(this,'u='+urlencode(this.href)+'&r=&i=&a=shp_gui.resultcount');" target="_blank">1,575,956</a>건</p> <div class="group_item"> <div class="tab_item"> <ul class="lst_tab _main_tab"> <li class="first tab _tab selected"> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*a.tab');"> <span class="sbar"><span></span></span> <span class="name" title="전체상품">전체상품</span> </a> </li> <li class="tab _tab"> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*h.tab');"> <span class="sbar"><span></span></span> <span class="name" title="핫딜">핫딜</span> </a> </li> <li class="tab _tab "> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*m.tab');"> <span class="sbar"><span></span></span> <span class="name" title="제조사">제조사</span> </a> </li> <li class="tab _tab "> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*3.tab');"> <span class="sbar"><span></span></span> <span class="name" title="유형">유형</span> </a> </li> <li class="tab _tab "> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*6.tab');"> <span class="sbar"><span></span></span> <span class="name" title="멀티스타일">멀티스타일</span> </a> </li> </ul> <div class="tab_sub"> <div class="dsc_info _sub_tab_area" style="display:block;"><span class="spshop ico_info"></span>네이버는 상품판매의 당사자가 아니며, 구매 전 상품정보를 반드시 확인하시기 바랍니다. <a href="https://shopping.naver.com/user/legalbasis.nhn" target="_blank" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&r=&i=&a=shp_gui.law');">법적고지 및 안내</a><span class="spshop ico_arr"></span></div> <div class="dsc_info _sub_tab_area" style="display:none;"><span class="spshop ico_info"></span>네이버는 상품판매의 당사자가 아니며, 구매 전 상품정보를 반드시 확인하시기 바랍니다. <a href="https://shopping.naver.com/user/legalbasis.nhn" target="_blank" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&r=&i=&a=shp_gui.law');">법적고지 및 안내</a><span class="spshop ico_arr"></span></div> <ul class="lst_sub_tab _sub_tab_area" style="display:none;"> <li class='tab _tab first selected'> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*m.tab&g=maker_9317');"> <span class="dot"></span> <span class="name" title="LG전자">LG전자</span> <span class="spshop ico_arr">선택됨</span> </a> </li> <li class='tab _tab '> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*m.tab&g=maker_3675');"> <span class="dot"></span> <span class="name" title="삼성전자">삼성전자</span> <span class="spshop ico_arr">선택됨</span> </a> </li>  ...
#         var _elAdIndLayerBz = null;
#         var _elAdIndLayerTimeBz;
#         var _elDscNcautionBz = null;
#
#         function adInfoShowBz(el) {
#             if (_elAdIndLayerBz) {
#                 adInfoHideBz();
#                 return false;
#             } else {
#                 if (!_elDscNcautionBz) {
#                     _elDscNcautionBz = $Element(el).parent();
#                 }
#                 _elDscNcautionBz._element.style.zIndex = 121;
#                 _elAdIndLayerBz = $Element(el).next();
#                 _elAdIndLayerBz.show();
#                 _elAdIndLayerTimeBz = (new Date()).getTime();
#                 return true;
#             }
#         }
#
#         function adInfoHideBz() {
#             if (_elAdIndLayerBz) {
#                 if (_elDscNcautionBz) {
#                     _elDscNcautionBz._element.style.zIndex = 0;
#                 }
#                 _elAdIndLayerBz.hide();
#                 _elAdIndLayerBz = null;
#             }
#         }
#
#         function adInfoHideClickEventHandlerBz(e) {
#             if (_elAdIndLayerTimeBz + 200 < (new Date()).getTime()) adInfoHideBz();
#         }
#
#         document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerBz, false);
#     </script>
#     <div class="ad_section section _bz_section bg_type_v2">
#         <div class="section_head"><h2>비즈사이트</h2>
#             <div class="dsc_ncaution">
#               <span><em class="dsc_ncaution_quotation">&lsquo;</em><strong class="dsc_ncaution_keyword">에어컨</strong><em class="dsc_ncaution_quotation">&rsquo;</em></span>
#               <span class="dsc_ncaution_text">관련 광고입니다.</span>
#                 <a class="ico_ad_dsc" href="javascript:void(0);" title="이 광고가 표시된 이유" onclick="if(adInfoShowBz(this)) goOtherCR(this, &#39;a=biz_nop.adset&amp;r=0&amp;i=biz_nopadset&amp;u=&#39;+urlencode(this.href));">이 광고가 표시된 이유</a>
#                 <div class="ly_ad_dsc" onclick="adInfoHideBz();" style="display:none"><span class="ico_arr">&nbsp;</span>
#                     <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
#                     <button class="bt_ad_clse" title="안내 레이어 닫기" type="button">안내 레이어 닫기</button>
#                 </div>
#             </div>
#             <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" target="_blank" onclick="return goOtherCR(this, &#39;a=biz_nop.registration&amp;r=0&amp;i=biz_nopregistration&amp;u=&#39;+urlencode(this.href));">등록 안내</a></div>
#         <div class="ad_area nx_power" id="biz_site_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=k7QT1sFTHaNSJTO5_hV-P3aXmnN5bx-...">
#             <ul class="lst_type ">
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="0" class="lst lst1">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=E/PswW+fyJ6pm+mvVCTQPv///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=1&amp;i=nad-a001-01-000000056338746&amp;d=&#39; + urlencode(&#39;http://rental-day.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">에어컨 특가 렌탈데이</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=E/PswW+fyJ6pm+mvVCTQPv///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=1&amp;i=nad-a001-01-000000056338746&amp;d=&#39;+urlencode(&#39;http://rental-day.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">rental-day.com</a>
#
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=E/PswW+fyJ6pm+mvVCTQPv///w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=1&amp;i=nad-a001-01-000000056338746&amp;d=&#39;+urlencode(&#39;http://rental-day.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 <strong class='hl'>에어컨</strong>특가 <strong class='hl'>에어컨</strong>, 렌탈 신청 시 전제품 무료배송+무료설치,3년 무상 A/S
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="1" class="lst lst2">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=x0Jh4vw/q2mzaxHv3FwAcP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=2&amp;i=nad-a001-01-000000051047150&amp;d=&#39; + urlencode(&#39;https://cafe.naver.com/tjd9150&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">예산에어컨-가나시스템에어컨</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=x0Jh4vw/q2mzaxHv3FwAcP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=2&amp;i=nad-a001-01-000000051047150&amp;d=&#39;+urlencode(&#39;https://cafe.naver.com/tjd9150&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">cafe.naver.com/tjd9150</a>
#
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=x0Jh4vw/q2mzaxHv3FwAcP///w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=2&amp;i=nad-a001-01-000000051047150&amp;d=&#39;+urlencode(&#39;https://cafe.naver.com/tjd9150&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 타업체대비 저렴,친절,신속,정확,중고,신품 <strong class='hl'>에어컨</strong> 냉,난방기 설치,판매 상담환영
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="2" class="lst lst3">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=sDMTmdmWqA+LKnOKKdZNCf///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=3&amp;i=nad-a001-01-000000035155902&amp;d=&#39; + urlencode(&#39;http://jack00act1.koreafree.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">에어컨 에어컨천국</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=sDMTmdmWqA+LKnOKKdZNCf///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=3&amp;i=nad-a001-01-000000035155902&amp;d=&#39;+urlencode(&#39;http://jack00act1.koreafree.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">jack00act1.koreafree.co.kr</a>
#
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=sDMTmdmWqA+LKnOKKdZNCf///w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=3&amp;i=nad-a001-01-000000035155902&amp;d=&#39;+urlencode(&#39;http://jack00act1.koreafree.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 삼성 LG 캐리어 <strong class='hl'>에어컨</strong> 간편견적, 정평설계, 책임시공, 고객맞춤상담,냉난방기
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="3" class="lst lst4">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=6zz4AopJGciP69L61mL/xP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=4&amp;i=nad-a001-01-000000002493379&amp;d=&#39; + urlencode(&#39;http://cariermall.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">캐리어에어컨전문 캐리어몰</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=6zz4AopJGciP69L61mL/xP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=4&amp;i=nad-a001-01-000000002493379&amp;d=&#39;+urlencode(&#39;http://cariermall.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">cariermall.com</a>
#
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=6zz4AopJGciP69L61mL/xP///w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=4&amp;i=nad-a001-01-000000002493379&amp;d=&#39;+urlencode(&#39;http://cariermall.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 캐리어 <strong class='hl'>에어컨</strong>판매전문, 전국 230여 직영A/S센터, 정품공식몰, 기본설치무료!
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="4" class="lst lst5">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=jSzB90cOQ1qGFGh3a7qdv////w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=5&amp;i=nad-a001-01-000000056280143&amp;d=&#39; + urlencode(&#39;https://smartstore.naver.com/smartgage&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">LG 공식판매 (주)대명유통</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=jSzB90cOQ1qGFGh3a7qdv////w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000056280143&amp;d=&#39;+urlencode(&#39;https://smartstore.naver.com/smartgage&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">smartstore.naver.com/smartgage</a>
#             <span class="ico_area">
#               <span class="ico">
#                 <span alt="네이버페이" class="sp_ad ico_npay" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
#                 <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank" onclick="return goOtherCR(this, &#39;a=biz_nop.checkout&amp;r=5&amp;i=nad-a001-01-000000056280143&amp;u=&#39;+urlencode(this.href));">
#                   <span class="ly_box">
#                     <p>네이버 아이디 하나로 간편구매</p>
#                     <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
#                   </span>
#                     <span class="sp_ad ly_tail"></span>
#                 </a>
#               </span>
#
#
#
#             </span>
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=jSzB90cOQ1qGFGh3a7qdv////w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=5&amp;i=nad-a001-01-000000056280143&amp;d=&#39;+urlencode(&#39;https://smartstore.naver.com/smartgage&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 LG전자 온라인 공식판매점 (주)대명유통
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#             </ul>
#         </div>
#
#         <div class="ad_banner">
#             <span class="sp_ad ico_npay">네이버페이</span>마크는 네이버ID로 편리하고 안전하게 구매할 수 있는 네이버페이 사용처에 표시됩니다.<br />
#             네이버페이 사용처에서 구매하시면 네이버페이 포인트를 적립해드립니다.
#             <a class="more_mileage" href="//event2.pay.naver.com/event/benefit/list?frm=sa" onclick="return goOtherCR(this, 'a=mib_biz.banner&r=0&i=mib_bizbanner&u='+urlencode(this.href));" target="_blank">혜택 자세히 보기</a>
#         </div>
#         <div class="section_more">
#             <a class="go_site" target="_blank" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%97%90%EC%96%B4%EC%BB%A8&amp;referenceId=U5l0ilpySDlssaCo1%2FRssssstdo-403283&amp;bucket=0" onclick="return goOtherCR(this, &#39;a=biz_nop.more&amp;r=1&amp;i=bizmore&amp;u=&#39;+urlencode(this.href));">더보기</a>
#         </div>
#     </div><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_kindic_180830.css"> <script type="text/javascript"> function wiki_escape(url) { if (navigator.appName.charAt(0) == "M" && navigator.appVersion.indexOf("MSIE 6") != -1) { tmp = escape(url); ret = tmp.replace("http\%3A", "http:"); } else if (navigator.appName.indexOf("Opera") != -1) { len = url.length; last_pos = url.lastIndexOf("/"); url_prefix = url.substr(0, last_pos + 1); url_item = url.substr(last_pos + 1, len - last_pos); ret = url_prefix + (encodeURIComponent(url_item)); } else ret = url; return ret; } </script> <div class="sp_kindic sc _sp_kindic"> <div class="sc_head"> <h2>지식백과</h2> </div> <div class="sc_kindic"> <div class="group_kindic type_attach"> <div class="kindic"> <div class="thumb_area " id="kdic_thumb_1"> <a target="_blank" href="https://terms.naver.com/entry.nhn?docId=1063140&cid=40942&categoryId=32351" class="link_thumb" onclick="return goOtherCR(this,'a=kdc_gnl*D.thumb&r=1&i=88000010_000000000000000000003e20&u='+urlencode(this.href));"> <img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F2765_000_2%2F20151118181647978_0II11U6QM.gif%2F15904_0.gif%3Ftype%3Dw450_fst%23450x314&type=mfullfill160_160" onload="this.parentNode.className='link_thumb';" onerror="this.parentNode.style.display='none';" width="80" height="80" class="thumb" alt=""><span class="thumb_bd"></span></a> </div> <div class="info_area"> <div class="tit_box"> <a target="_blank" href="https://terms.naver.com/entry.nhn?docId=1063140&cid=40942&categoryId=32351" class="tit type_dsc" onclick="return goOtherCR(this,'a=kdc_gnl*D.title&r=1&i=88000010_000000000000000000003e20&u='+urlencode(this.href));"> <strong>에어컨</strong> </a> <a target="_blank" href="https://terms.naver.com/entry.nhn?docId=1063140&cid=40942&categoryId=32351" class="dsc" onclick="return goOtherCR(this,'a=kdc_gnl*D.title&r=1&i=88000010_000000000000000000003e20&u='+urlencode(this.href));">실내온도를 낮추거나 쾌적한 상태로 유지하게 하는 기계장치</a> </div> <p class="txt_box"> 실내온도를 낮추거나 쾌적한 상태로 유지하게 하는 기계장치. 여름에 주로 이용하기 때문에 냉방장치(冷房裝置)라고도 부른다. 일정한 공간을 인간이 활동하기에... </p> <div class="source_box"><span class="source">두산백과</span><span class="source"><a href="https://terms.naver.com/list.nhn?cid=40942&categoryId=32350" target="_blank" title="지식백과 색인 목록" onclick="return goOtherCR(this,'a=kdc_gnl*D.category&r=1&i=88000010_000000000000000000003e20&u='+urlencode(this.href));">기계공학</a> &gt; <a href="https://terms.naver.com/list.nhn?cid=40942&categoryId=32351" target="_blank" title="지식백과 색인 목록" onclick="return goOtherCR(this,'a=kdc_gnl*D.category&r=1&i=88000010_000000000000000000003e20&u='+urlencode(this.href));">기계공학일반</a></span> </div> </div> </div> <div class="kindic"> <div class="thumb_area " id="kdic_thumb_2"> <a target="_blank" href="https://terms.naver.com/entry.nhn?docId=2464260&cid=51399&categoryId=51399" class="link_thumb" onclick="return goOtherCR(this,'a=kdc_gnl*K.thumb&r=2&i=8814ccb9_000000005fbc014bfd26a3a4&u='+urlencode(this.href));"> <img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3745_000_4%2F20150319101355741_9QNRTSUE1.jpg%2Ffh2_55002848_i1.jpg%3Ftype%3Dw450_fst%23170x170%23c170&type=n_mfullfill160_160" onload="this.parentNode.className='link_thumb';" onerror="this.parentNode.style.display='none';" width="80" height="80" class="thumb" alt=""><span class="thumb_bd"></span></a> </div> <div class="info_area"> <div class="tit_box"> <a target="_blank" href="https://terms.naver.com/entry.nhn?docId=2464260&cid=51399&categoryId=51399" class="tit " onclick="return goOtherCR(this,'a=kdc_gnl*K.title&r=2&i=8814ccb9_000000005fbc014bfd26a3a4&u='+urlencode(this.href));"> <strong>에어컨</strong> </a> </div> <p class="txt_box">제품에 따라 난방이 가능한 제품은 겨울철 히터로도 사용할 수 있습니다. 제품에 따라 공기청정, 습기제거, 가습기능 등 다양한 기능이 있습니다. <strong>에어컨</strong></p> <div class="source_box"><span class="source">쇼핑용어사전</span><span class="source"><a href="https://terms.naver.com/l ...
#
#
#  <script type="text/javascript"> /* thumnail 처리 */ function on_realtime_nxtab_noimage(img, type ) { img.onerror=null; img.src="https://ssl.pstatic.net/sstatic/search/img3/img_profile_twitter5.png"; img.alt="이미지 준비중"; img.width="50"; img.height="50"; } </script> <div class="realtime2 section _prs_rea_doc" id="realTimeSearchBody"> <div class="section_head"> <h2>실시간검색</h2> <a href="https://help.naver.com/support/alias/search/integration/integration_7.naver" target="_blank" class="link_help" onclick="return goOtherCR(this, 'a=rea.help&r=0&i=0&u='+urlencode(this.href));"><i class="sprenew api_ico_help">도움말</i></a> <p class="title_desc sort"> <strong>최신</strong> <span class="bar"></span> <a href="?where=realtime&sm=tab_smr&query=%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&best=1" onclick="return goOtherCR(this, 'a=rea.pop&r=0&i=0&u='+urlencode(this.href));" >인기</a> </p> <div class="rt_update"><span class="update_state"></span></div> </div> <h3 class="blind">최신순</h3> <div class="rt_wrap rt_wrap2"> <div> <ul class="type01"> <li class="rt_mt first_child"> <div class="thumb"> <a target="_blank" href="https://twitter.com/syslsi3" crlink="a=rea_doc*t.img&r=&i=a00000fa_7f84a3d0a6ec3b776ab2f9a4&ps=&nd=&u=" ><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fpbs.twimg.com%2Fprofile_images%2F1098304746794868736%2F0KwURWW1_bigger.jpg&type=o50_50_re2" alt="syslsi3 썸네일" width="50" height="50" onError="on_realtime_nxtab_noimage(this, 'twitter');"><span class="mask"></span><span class="valign"></span> </a> </div> <dl> <dd><a href="https://twitter.com/syslsi3" class="rt_user" target="_blank" crlink="a=rea_doc*t.id&r=&i=a00000fa_7f84a3d0a6ec3b776ab2f9a4&ps=&nd=&u=" ><span class="user_name">star★</span> <span class="user_id">@syslsi3</span></a></dd> <dd> <span class="cmmt _twitter" data-src="https://twitter.com/syslsi3/status/1109994406633861120" crlink="a=rea_doc*t.text&r=&i=a00000fa_7f84a3d0a6ec3b776ab2f9a4&ps=&nd=&u=">왜 추운가 했더니 <strong class="hl">에어컨</strong> 틀었네ㅋ 시바</span> </dd> <dd class="rt_sub _rt_time _time_1553478263"> <div class="sub_area"> <a target="_blank" href="http://twitter.com" class="sub_twtime" crlink="a=rea_doc*t.logo&r=&i=a00000fa_7f84a3d0a6ec3b776ab2f9a4&ps=&nd=&u=" ><img src="https://ssl.pstatic.net/sstatic/search/img3/ico_twitter2.gif" width="13" height="11" alt="트위터"></a><a target="_blank" href="https://twitter.com/syslsi3/status/1109994406633861120" class="time _timeinfo" crlink="a=rea_doc*t.time&r=&i=a00000fa_7f84a3d0a6ec3b776ab2f9a4&ps=&nd=&u=" >8분 전</a> <span class="bar"></span> <span class="sub_retweet">리트윗 0</span> <span class="bar"></span> <span class="sub_interest">관심글 0</span> </div> </dd> </dl> <div class="rt_btn_wrap"> <a href="https://twitter.com/intent/tweet?in_reply_to=1109994406633861120" class="rt_btn" crlink="a=rea_doc*t.reply&r=&i=a00000fa_7f84a3d0a6ec3b776ab2f9a4&ps=&nd=&u=" target="_blank"><span class="sprt ico_reply"></span>답글</a><a href="https://twitter.com/intent/retweet?tweet_id=1109994406633861120" class="rt_btn" crlink="a=rea_doc*t.rt&r=&i=a00000fa_7f84a3d0a6ec3b776ab2f9a4&ps=&nd=&u=" target="_blank"><span class="sprt ico_rt"></span>리트윗</a><a href="https://twitter.com/intent/favorite?tweet_id=1109994406633861120" class="rt_btn" crlink="a=rea_doc*t.favorite&r=&i=a00000fa_7f84a3d0a6ec3b776ab2f9a4&ps=&nd=&u=" target="_blank"><span class="sprt ico_interest"></span>관심글</a> </div> </li> <li class=""> <div class="thumb"> <a href="http://cafe.naver.com/ilovecat/5617191" target="_blank" crlink="a=rea_doc*z.img&r=&i=9018b4cf_99a81b55b6276a04664&ps=&nd=&u=" ><img src="https://ssl.pstatic.net/sstatic/search/pc/2016/img/ico_rt_cafe.png" width="50" height="50" alt="카페 댓글"> <span class="mask"></span> <span class="valign"></span> </a> </div> <dl> <dd> <a href="http://cafe.naver.com/ilovecat/5617191" class="rt_user" target="_blank" crlink="a=rea_doc*z.id&r=&i=9018b4cf_99a81b55b6276a04664&ps=&nd=&u=" ><span class="user_name">stev******</span></a> </dd> <dd> <a href="http://cafe.naver.com/ilovecat/5617191" class="t ...
# <div class="collection"></div> </div><div id="sub_pack" class="sub_pack"><a href="https://alpha.naver.com/experiment/newnaverapp/beta?id=srh" target="_blank" onclick="return goOtherCR(this, 'a=bnr.link&r=&i=&u='+urlencode(this.href));" class="api_banner" style="background-color:#fff;"><img src="https://ssl.pstatic.net/sstatic/search/pc/tmp/ban_app_v3.png" width="400" height="60" class="img" alt="이제 iOS에서도 ‘새로운 네이버’를 경험해 보세요 이용방법 보기"></a><div class="z_aside section rktshp"> <div class="section_head"> <h2>에어컨/냉방기 쇼핑검색어</h2> </div> <div class="realtime_srch"> <ol class="lst_realtime_srch"> <li> <a href="?query=%EB%B2%BD%EA%B1%B8%EC%9D%B4%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="벽걸이에어컨" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=1')"> <span class="keyword"> <em class="num">1</em> <span class="tit">벽걸이에어컨</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">1</span></em> </a> </li> <li> <a href="?query=%ED%9C%B4%EB%8C%80%EC%9A%A9%EC%84%A0%ED%92%8D%EA%B8%B0&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="휴대용선풍기" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=2')"> <span class="keyword"> <em class="num">2</em> <span class="tit">휴대용선풍기</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">1</span></em> </a> </li> <li> <a href="?query=%EC%82%BC%EC%84%B1%EB%AC%B4%ED%92%8D%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="삼성무풍에어컨" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=3')"> <span class="keyword"> <em class="num">3</em> <span class="tit">삼성무풍에어컨</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">2</span></em> </a> </li> <li> <a href="?query=2IN1%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="2IN1에어컨" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=4')"> <span class="keyword"> <em class="num">4</em> <span class="tit">2IN1에어컨</span> </span> <em class="rank equal"><span class="spim">동일</span><span class="count">0</span></em> </a> </li> <li> <a href="?query=LG%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="LG에어컨" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=5')"> <span class="keyword"> <em class="num">5</em> <span class="tit">LG에어컨</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">1</span></em> </a> </li> <li> <a href="?query=%EC%82%BC%EC%84%B1%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="삼성에어컨" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=6')"> <span class="keyword"> <em class="num">6</em> <span class="tit">삼성에어컨</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">1</span></em> </a> </li> <li> <a href="?query=LG%EC%97%90%EC%96%B4%EC%BB%A82IN1&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="LG에어컨2IN1" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=7')"> <span class="keyword"> <em class="num">7</em> <span class="tit">LG에어컨2IN1</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">4</span></em> </a> </li> <li> <a href="?query=%EC%BA%90%EB%A6%AC%EC%96%B4%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="캐리어에어컨" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=8')"> <span class=" ...
