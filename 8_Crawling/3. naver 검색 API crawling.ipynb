# %%
import urllib.request
import bs4
import os
import sys

# %%
client_id = "20uqHAr39TBYdOu4URT"
client_secret = "lI2Bsf3dps"
encText = urllib.parse.quote("에어컨")
url ="https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EC%97%90%EC%96%B4%EC%BB%A8"

# %%
request = urllib.request.Request(url)

# %%
request.add_header("X-Naver.Client-Id", client_id)
request.add_header("X-Naver.Client-Secret", client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

# %%
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="에어컨 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'에어컨'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'에어컨'의 네이버 통합검색 결과입니다."> <title>에어컨 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_140327.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_190221.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_190221.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/api_atcmp_181122.css"><script type="text/javascript"> naver = window.naver || {}; naver.search = naver.search || {}; var g_D = 0 ; if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } function urlencode (q) { return escape(q).replace(/\+/g, "%2B") ; } function urlexpand (url) { var href = document.location.href ; if (url == "") return href ; if (url.match(/^[-.A-Za-z]+:/)) return url ; if (url.charAt(0) == '#') return href.split("#")[0] + url ; if (url.charAt(0) == '?') return href.split("?")[0] + url ; if (url.charAt(0) == '/') return href.replace(/([^:\/])\/.*$/, "$1") + url ; return href.substring(0, href.lastIndexOf("/")+1) + url ; } naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + "; expires=" + exdate.toUTCString(); } } cookie = cookie + "; path=/"; if (domain != null) { cookie = cookie + "; domain=" + domain; } document.cookie = cookie; }, get : function (key) { var cookie_list = document.cookie.split(/\s*;\s*/); for (var i = 0; i < cookie_list.length; i++) { var tmp_list = cookie_list[i].split("="); var c_key = tmp_list[0].trim(); var c_value = tmp_list[1]; if (key == c_key) { return unescape(c_value); } } return null; } } })(); naver.search.https = window.location.protocol == "https:"; naver.search.meta_referrer = 0; var _nx_js_load = (function () { var scrs = {} ; return function (script, callback) { scrs[script] = {} ; scrs[script].domscript = document.createElement('script'); scrs[script].domscript.src = script ; if (callback) scrs[script].callback = (callback instanceof Array) ? callback : [callback]; scrs[script].domscript.onloadDone = false; scrs[script].domscript.onload = function() { scrs[script].domscript.onloadDone = true; if (scrs[script].callback) { for (var i = 0; i < scrs[script].callback.length; i++) { scrs[script].callback[i]() ; } } scrs[script].domscript.onload = scrs[script].domscript.onreadystatechange = null; } ; scrs[script].domscript.onreadystatechange = function() { if ( ("loaded" === scrs[script].domscript.readyState || "complete" === scrs[script].domscript.readyState) && !scrs[script].domscript.onloadDone ) { scrs[script].domscript.onload(); } } ; document.getElementsByTagName('head')[0].append ...
#
# <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#         NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#         NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#         var parentElement = $Element(element).parent();
#         var timerAttribute = parentElement.attr("data-timer");
#         if (timerAttribute) {
#             clearTimeout(timerAttribute);
#             parentElement.attr("data-timer", "");
#         }
#         var tooltipElement = $Element(parentElement.query("._tooltip"));
#         tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#         var parentElement = $Element(element).parent();
#         if (!parentElement.attr("data-timer")) {
#             var timer = setTimeout(function () {
#                 var tooltipElement = $Element(parentElement.query("._tooltip"));
#                 tooltipElement.css("display", "none");
#             }, 100);
#             parentElement.attr("data-timer", timer);
#         }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#         if (_elAdIndLayerPl) {
#             adInfoHidePl();
#             return false;
#         } else {
#             if (!_elDscNcautionPl) {
#                 _elDscNcautionPl = $Element(el).parent();
#             }
#             _elDscNcautionPl._element.style.zIndex = 121;
#             _elAdIndLayerPl = $Element(el).next();
#             _elAdIndLayerPl.show();
#             _elAdIndLayerTimePl = (new Date()).getTime();
#             return true;
#         }
#     }
#
#     function adInfoHidePl() {
#         if (_elAdIndLayerPl) {
#             if (_elDscNcautionPl) {
#                 _elDscNcautionPl._element.style.zIndex = 0;
#             }
#             _elAdIndLayerPl.hide();
#             _elAdIndLayerPl = null;
#         }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#         if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
# </script>
# <link href="https://ssl.pstatic.net/sstatic/search/sa/180906/css/sa.css" rel="stylesheet" type="text/css" />
# <link href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css" rel="stylesheet" type="text/css" />
# <div class="ad_section section _pl_section bg_type_v2">
#     <div class="section_head"><h2>파워링크</h2>
#
#         <div class="dsc_ncaution">
#           <span><em class="dsc_ncaution_quotation">&lsquo;</em><strong class="dsc_ncaution_keyword">에어컨</strong><em class="dsc_ncaution_quotation">&rsquo;</em></span>
#           <span class="dsc_ncaution_text">관련 광고입니다.</span>
#           <a class="ico_ad_dsc" href="javascript:void(0);" title="이 광고가 표시된 이유" onclick="if(adInfoShowPl(this)) goOtherCR(this, &#39;a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u=&#39;+urlencode(this.href));">이 광고가 표시된 이유</a>
#
#           <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none"><span class="ico_arr">&nbsp;</span>
#
#               <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
#               <button class="bt_ad_clse" title="안내 레이어 닫기" type="button">안내 레이어 닫기</button>
#           </div>
#         </div>
#         <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u=&#39;+urlencode(this.href));">등록 안내</a>
#     </div>
#     <div class="ad_area nx_power" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=GLIND_0KgCtcqkAWl8v_trpV_...">
#         <ul class="lst_type">
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="0" class="lst lst1">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=6pECbMlUkHHyg21lc61Vj////w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000036168794&amp;d=&#39; + urlencode(&#39;http://www.cjhello.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">CJ 헬로 공식 렌탈샵</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=6pECbMlUkHHyg21lc61Vj////w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000036168794&amp;d=&#39;+urlencode(&#39;http://www.cjhello.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.cjhello.com</a>
#
#                     <p class="ad_dsc">
#                       <strong class='hl'>에어컨</strong>, 월 20,800원으로 부담없이 사용하자! A/S 3년 보장은 기본!
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="1" class="lst lst2">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=9HeqNHLUY/g3UhMT+95PQv///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000030606496&amp;d=&#39; + urlencode(&#39;http://whisen.lge.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">LG 휘센 씽큐</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=9HeqNHLUY/g3UhMT+95PQv///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000030606496&amp;d=&#39;+urlencode(&#39;http://whisen.lge.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">whisen.lge.co.kr</a>
#
#                     <p class="ad_dsc">
#                       365일 인공지능 씽큐로 공간학습 상황학습 사용패턴학습. 인공지능 스스로 <strong class='hl'>에어컨</strong>.
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="2" class="lst lst3">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=3whfPQ1sIKVxoc1PbG5kPP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000057172446&amp;d=&#39; + urlencode(&#39;http://www.coupang.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">에어컨 쿠팡</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=3whfPQ1sIKVxoc1PbG5kPP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000057172446&amp;d=&#39;+urlencode(&#39;http://www.coupang.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.coupang.com</a>
#
#                     <p class="ad_dsc">
#                       <strong class='hl'>에어컨</strong> 특가! 냉방가전, 벽걸이형<strong class='hl'>에어컨</strong>, 똑똑한 선택, 가전제품은 쿠팡.
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="3" class="lst lst4">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=lwBaKPtyhhPvC1wS/iQitP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000056947549&amp;d=&#39; + urlencode(&#39;http://www.gmarket.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">G마켓 에어컨</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=lwBaKPtyhhPvC1wS/iQitP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000056947549&amp;d=&#39;+urlencode(&#39;http://www.gmarket.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.gmarket.co.kr</a>
#
#                     <p class="ad_dsc">
#                       쇼핑을 바꾸는 쇼핑! <strong class='hl'>에어컨</strong> 1년 내내 매일 무료배송 + 첫 구매는 누구나 30%
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="4" class="lst lst5">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=DVyw7yIflsCup/WrYzGkhv///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=5&amp;i=nad-a001-01-000000056280294&amp;d=&#39; + urlencode(&#39;https://smartstore.naver.com/smartgage&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">LG 공식판매 (주)대명유통</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=DVyw7yIflsCup/WrYzGkhv///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000056280294&amp;d=&#39;+urlencode(&#39;https://smartstore.naver.com/smartgage&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">smartstore.naver.com/smartgage</a>
#           <span class="ico_area">
#             <span class="ico">
#               <span alt="네이버페이" class="sp_ad ico_npay" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
#               <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.checkout&amp;r=5&amp;i=nad-a001-01-000000056280294&amp;u=&#39;+urlencode(this.href));">
#                 <span class="ly_box">
#                   <p>네이버 아이디 하나로 간편구매</p>
#                   <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
#                 </span>
#                   <span class="sp_ad ly_tail"></span>
#               </a>
#             </span>
#
#
#
#           </span>
#                     <p class="ad_dsc">
#                       LG전자 온라인 공식판매점 (주)대명유통
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="5" class="lst lst6">
#                 <div class="line"></div>
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=xkkSpAh79m/YEO+29d22Gv///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000057006512&amp;d=&#39; + urlencode(&#39;http://www.auction.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">에어컨 옥션</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=xkkSpAh79m/YEO+29d22Gv///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000057006512&amp;d=&#39;+urlencode(&#39;http://www.auction.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.auction.co.kr</a>
#
#                     <p class="ad_dsc">
#                       쇼핑이 생각날 땐, 어서 옥션! <strong class='hl'>에어컨</strong>, ALL-KILL특가+최대12%할인쿠폰!
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="6" class="lst lst7">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=tbZ5S02k9SWWE4Mpne+YAP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=7&amp;i=nad-a001-01-000000056243736&amp;d=&#39; + urlencode(&#39;http://www.systemairlg.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">MS시스템에어컨 전문설치기업</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=tbZ5S02k9SWWE4Mpne+YAP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000056243736&amp;d=&#39;+urlencode(&#39;http://www.systemairlg.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.systemairlg.co.kr</a>
#
#                     <p class="ad_dsc">
#                       LG시스템<strong class='hl'>에어컨</strong> 설계 판매 매입 시공 유지보수전문점 무상A/S 2년
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="7" class="lst lst8">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=KXVKQahrf2quHGW9Zy+qdf///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=8&amp;i=nad-a001-01-000000054894530&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/life2010&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">인하 에어컨설치  15만원</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=KXVKQahrf2quHGW9Zy+qdf///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=8&amp;i=nad-a001-01-000000054894530&amp;d=&#39;+urlencode(&#39;https://blog.naver.com/life2010&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">blog.naver.com/life2010</a>
#
#                     <p class="ad_dsc">
#                       출장비무료, 서울,경기,인천전지역, 당일설치,<strong class='hl'>에어컨</strong>수리, 카드결재,2년무상 A/S
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="8" class="lst lst9">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=h2Y5PMdOPeYiCQ3QUubtq////w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=9&amp;i=nad-a001-01-000000009996984&amp;d=&#39; + urlencode(&#39;http://www.danawa.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">에어컨 다나와</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=h2Y5PMdOPeYiCQ3QUubtq////w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=9&amp;i=nad-a001-01-000000009996984&amp;d=&#39;+urlencode(&#39;http://www.danawa.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.danawa.com</a>
#           <span class="ico_area">
#
#             <span class="ico">
#               <span class="sp_ad ico_nlogin" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
#               <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" onclick="return goOtherCR(this, &#39;a=pwl_nop.naverlogin&amp;r=9&amp;i=nad-a001-01-000000009996984&amp;u=&#39;+urlencode(this.href));">
#                 <span class="ly_box">
#                   <p>네이버 아이디로 로그인이 가능합니다.</p>
#                   <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
#                 </span>
#                   <span class="sp_ad ly_tail"></span>
#               </a>
#             </span>
#
#
#           </span>
#                     <p class="ad_dsc">
#                       <strong class='hl'>에어컨</strong>, 살 땐 사더라도 최저가로 알뜰쇼핑 하셔야죠! 가격비교 다나와!
#
#                     </p>
#
#                 </div>
#             </li>
#             <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="9" class="lst lst10">
#
#                 <div class="inner">
#                     <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=IxlaSHJHHx7gw+ylEZAyyP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=10&amp;i=nad-a001-01-000000025501480&amp;d=&#39; + urlencode(&#39;http://blog.naver.com/lyysun&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">강동구 송파구  에어컨 설치</a>
#
#                     <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=IxlaSHJHHx7gw+ylEZAyyP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=10&amp;i=nad-a001-01-000000025501480&amp;d=&#39;+urlencode(&#39;http://blog.naver.com/lyysun&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">blog.naver.com/lyysun</a>
#
#                     <p class="ad_dsc">
#                       강동 /송파구/냉난방/<strong class='hl'>에어컨</strong>설치.가스충전.중고매입판매/<strong class='hl'>에어컨</strong>직접견적 직접설치
#
#                     </p>
#
#                 </div>
#             </li>
#         </ul>
#     </div>
#
#
#     <div class="section_more">
#         <a class="go_site" target="_blank" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%97%90%EC%96%B4%EC%BB%A8&amp;referenceId=U5PK1dpVuFZssu7r%2FShssssssGG-113508&amp;bucket=0" onclick="return goOtherCR(this, &#39;a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u=&#39;+urlencode(this.href));">더보기</a>
#     </div>
# </div><script crossorigin="anonymous" src="https://ssl.pstatic.net/adimg3.search/adpost/js/event_tracker.js?o=search"></script>
#
# <script type="text/javascript">
#     var _elAdIndLayerPwc = null;
#     var _elAdIndLayerTimePwc;
#     var _elDscNcautionPwc = null;
#
#     function adInfoShowPwc(el) {
#         if (_elAdIndLayerPwc) {
#             adInfoHidePwc();
#             return false;
#         } else {
#             if (!_elDscNcautionPwc) {
#                 _elDscNcautionPwc = $Element(el).parent();
#             }
#             _elDscNcautionPwc._element.style.zIndex = 121;
#             _elAdIndLayerPwc = $Element(el).next();
#             _elAdIndLayerPwc.show();
#             _elAdIndLayerTimePwc = (new Date()).getTime();
#             return true;
#         }
#     }
#
#     function adInfoHidePwc() {
#         if (_elAdIndLayerPwc) {
#             if (_elDscNcautionPwc) {
#                 _elDscNcautionPwc._element.style.zIndex = 0;
#             }
#             _elAdIndLayerPwc.hide();
#             _elAdIndLayerPwc = null;
#         }
#     };
#
#     function adInfoHideClickEventHandlerPwc(e) {
#         if (_elAdIndLayerTimePwc + 200 < (new Date()).getTime()) adInfoHidePwc();
#     };
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPwc, false); /*attach(window, "click");*/
# </script>
#
#     <link href="https://ssl.pstatic.net/sstatic/search/sa/power_contents/180905/css/sa_power_cnts.css" rel="stylesheet" type="text/css" />
#
#     <div class="ad_section section bg_type_v2">
#         <div class="section_head">
#             <h2>파워컨텐츠<span class="ia_beta">Beta</span></h2>
#
#             <div class="dsc_ncaution">
#                 <em>&lsquo;<strong>에어컨</strong>&rsquo;</em>
#                 관련 광고입니다.
#                 <a class="ico_ad_dsc" href="javascript:void(0);" title="이 광고가 표시된 이유" onclick="if(adInfoShowPwc(this)) goOtherCR(this, &#39;a=pwc_pro.info&amp;r=&amp;i=&amp;u=&#39; + urlencode(this.href));">이 광고가 표시된 이유</a>
#
#                 <div class="ly_ad_dsc" style="display:none">
#                     <span class="ico_arr">&nbsp;</span>
#
#                     <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
#                     <button class="bt_ad_clse" title="안내 레이어 닫기" type="button">안내 레이어 닫기</button>
#                 </div>
#             </div>
#             <a class="go_register space" href="http://saedu.naver.com/adbiz/searchad/powerContents.nhn" target="_blank" onclick="return goOtherCR(this, &#39;a=pwc_pro.reg&amp;r=0&amp;i=pwc_proregistration&amp;u=&#39; + urlencode(this.href));">파워컨텐츠 등록</a>
#         </div>
#         <div class="ad_area nx_power_cnts" id="power_contents_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=7MW8VhiWArS23f4KuGG_...">
#             <ul class="lst_type lst_type_v3">
#                 <li class="lst">
#                     <div class="ad_thumb">
#                         <a target="_blank" href="https://adcr.naver.com/adcr?x=VGTRj1YM/aJNWfuUhHH/n////w==...&amp;p=img" onclick="return goOtherCR(this, &#39;a=pwc_pro.img&amp;r=1&amp;i=nad-a001-03-000000056161079&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/sgsg-done&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">
#                             <img height="80" width="80" alt="2019년 &lt;strong class=&#39;hl&#39;&gt;에어컨&lt;/strong&gt; TOP5!" src="https://searchad-phinf.pstatic.net/MjAxOTAzMDdfODIg/MDAxNTUxOTY0ODA3MTE5.8aF7iUApMTO-JUHFtjfX72wbKi3fZNL9TFhuSATx1a8g.uSlMnw1vWhZw0igBKaJy0aL1iQkQslXRW0Gpy_unzMwg.PNG/976940-8a18655e-0d02-452e-812d-259f1401208d.png?type=f80_80" />
#                         </a>
#                     </div>
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=VGTRj1YM/aJNWfuUhHH/n////w==...&amp;p=tit" onclick="return goOtherCR(this, &#39;a=pwc_pro.tit&amp;r=1&amp;i=nad-a001-03-000000056161079&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/sgsg-done&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">2019년 <strong class='hl'>에어컨</strong> TOP5!</a>
#
#                         <p class="ad_date">2019.03.07.</p>
#
#                         <p class="ad_dsc">쓱싹에서 2019년 미리 유행할 <strong class='hl'>에어컨</strong>을 알아보고 누구보다 빠르게 남들과는 다른 여름을 준비하세요! 나에게 적합한 <strong class='hl'>에어컨</strong>은 어떤 걸까요? 2019년 여름 대세 <strong class='hl'>에어컨</strong> 순위를 함께 봅시다!...</p>
#
#                         <p class="ad_more">
#
#                             <a class="lnk_mall" target="_blank" href="https://adcr.naver.com/adcr?x=VGTRj1YM/aJNWfuUhHH/n////w==...&amp;p=company" onclick="return goOtherCR(this, &#39;a=pwc_pro.company&amp;r=1&amp;i=nad-a001-03-000000056161079&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/sgsg-done&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">쓱싹</a>
#                             <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=VGTRj1YM/aJNWfuUhHH/n////w==...&amp;p=url" onclick="return goOtherCR(this, &#39;a=pwc_pro.url&amp;r=1&amp;i=nad-a001-03-000000056161079&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/sgsg-done&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">https://blog.naver.com/sgsg-done</a>
#                         </p>
#                     </div>
#                 </li>
#                 <li class="lst">
#                     <div class="ad_thumb">
#                         <a target="_blank" href="https://adcr.naver.com/adcr?x=uOp7LiIsKsHG+12bsu/Dm////w==...&amp;p=img" onclick="return goOtherCR(this, &#39;a=pwc_pro.img&amp;r=2&amp;i=nad-a001-03-000000043754273&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/reoffice4278&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">
#                             <img height="80" width="80" alt="기업용 중고&lt;strong class=&#39;hl&#39;&gt;에어컨&lt;/strong&gt; 구매시 체크 리스트!" src="https://searchad-phinf.pstatic.net/MjAxODExMjNfMjcy/MDAxNTQyOTAwNDQ4MjM4.05oQPSrtakUioOMfqXKH4fiE9wE6Fw5n6u4vKt6jKuEg.vKB_a3T-F_i_SHRUTSDuSKqK28HAj1jk2WCRm0g9vdwg.PNG/grp-a001-03-000000008303220_020a43c9-0052-4392-b7f6-81b82e7a252a.png?type=f80_80" />
#                         </a>
#                     </div>
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=uOp7LiIsKsHG+12bsu/Dm////w==...&amp;p=tit" onclick="return goOtherCR(this, &#39;a=pwc_pro.tit&amp;r=2&amp;i=nad-a001-03-000000043754273&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/reoffice4278&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">기업용 중고<strong class='hl'>에어컨</strong> 구매시 체크 리스트!</a>
#
#                         <p class="ad_date">2018.10.05.</p>
#
#                         <p class="ad_dsc">기업에서 중고<strong class='hl'>에어컨</strong>을 구매한다면 믿을 수 있는 중고 업체를 찾아봐야 하는데 리싸이클오피스는 15년간의 사업 운영 노하우로 기업의 무료 방문견적부터 레이아웃 서비스부터 시작해 중고<strong class='hl'>에어컨</strong> 배송, 설치...</p>
#
#                         <p class="ad_more">
#
#                             <a class="lnk_mall" target="_blank" href="https://adcr.naver.com/adcr?x=uOp7LiIsKsHG+12bsu/Dm////w==...&amp;p=company" onclick="return goOtherCR(this, &#39;a=pwc_pro.company&amp;r=2&amp;i=nad-a001-03-000000043754273&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/reoffice4278&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">리싸이클오피스</a>
#                             <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=uOp7LiIsKsHG+12bsu/Dm////w==...&amp;p=url" onclick="return goOtherCR(this, &#39;a=pwc_pro.url&amp;r=2&amp;i=nad-a001-03-000000043754273&amp;d=&#39; + urlencode(&#39;https://blog.naver.com/reoffice4278&#39;) + &#39;&amp;u=&#39; + urlencode(this.href));">https://blog.naver.com/reoffice4278</a>
#                         </p>
#                     </div>
#                 </li>
#
#             </ul>
#         </div>
#
#     </div><script type="text/javascript"> _spt.anchor['a1'] = (new Date()).getTime() ; </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_shop_default_190131.css"> <script type="text/javascript">function shp_no_image(o, c) { o.onerror = null; o.src = 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif'; o.className = c; o.alt = '이미지 준비중';} </script> <div class="sp_shop_default section" id='_shopping_guide_view'> <div class="section_head"> <h2>네이버쇼핑</h2> <div class="dsc_ncaution2 _shopping_info_area"> <a href="#" onclick="return tCR('a=shp_gui.imark&r=&i=&u=javascript');" class="ico_ad_dsc _open_btn" title="이 정보가 표시된 이유">이 정보가 표시된 이유</a> <div class="ly_ad_dsc _layer" style="display:none;"> <span class="ico_arr">&nbsp;</span> <p>네이버가 운영하는 쇼핑 서비스입니다.</p> <button type="button" class="bt_ad_clse _close_btn" title="안내 레이어 닫기" onclick="return tCR('a=shp_gui.guideclose&r=&i=&u=javascript');">안내 레이어 닫기</button> </div> </div> <div class="dsc_ninfo">다른 사이트를 보시려면 <a href="?where=webkr&opt_src=site&sm=tab_shp&query=%EA%B0%80%EA%B2%A9%EB%B9%84%EA%B5%90%EC%82%AC%EC%9D%B4%ED%8A%B8+-%EB%84%A4%EC%9D%B4%EB%B2%84" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&r=&i=&a=shp_gui.pricesite');">여기</a>를 누르세요.</div> </div> <p class="title_desc title_desc_v2">'<em>에어컨</em>' 상품 <a href="https://search.shopping.naver.com/search/all.nhn?query=%EC%97%90%EC%96%B4%EC%BB%A8&frm=NVSCPRO" onclick="return goOtherCR(this,'u='+urlencode(this.href)+'&r=&i=&a=shp_gui.resultcount');" target="_blank">1,601,651</a>건</p> <div class="group_item"> <div class="tab_item"> <ul class="lst_tab _main_tab"> <li class="first tab _tab selected"> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*a.tab');"> <span class="sbar"><span></span></span> <span class="name" title="전체상품">전체상품</span> </a> </li> <li class="tab _tab"> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*h.tab');"> <span class="sbar"><span></span></span> <span class="name" title="핫딜">핫딜</span> </a> </li> <li class="tab _tab "> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*m.tab');"> <span class="sbar"><span></span></span> <span class="name" title="제조사">제조사</span> </a> </li> <li class="tab _tab "> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*3.tab');"> <span class="sbar"><span></span></span> <span class="name" title="유형">유형</span> </a> </li> <li class="tab _tab "> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*6.tab');"> <span class="sbar"><span></span></span> <span class="name" title="멀티스타일">멀티스타일</span> </a> </li> </ul> <div class="tab_sub"> <div class="dsc_info _sub_tab_area" style="display:block;"><span class="spshop ico_info"></span>네이버는 상품판매의 당사자가 아니며, 구매 전 상품정보를 반드시 확인하시기 바랍니다. <a href="https://shopping.naver.com/user/legalbasis.nhn" target="_blank" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&r=&i=&a=shp_gui.law');">법적고지 및 안내</a><span class="spshop ico_arr"></span></div> <div class="dsc_info _sub_tab_area" style="display:none;"><span class="spshop ico_info"></span>네이버는 상품판매의 당사자가 아니며, 구매 전 상품정보를 반드시 확인하시기 바랍니다. <a href="https://shopping.naver.com/user/legalbasis.nhn" target="_blank" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&r=&i=&a=shp_gui.law');">법적고지 및 안내</a><span class="spshop ico_arr"></span></div> <ul class="lst_sub_tab _sub_tab_area" style="display:none;"> <li class='tab _tab first selected'> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*m.tab&g=maker_9317');"> <span class="dot"></span> <span class="name" title="LG전자">LG전자</span> <span class="spshop ico_arr">선택됨</span> </a> </li> <li class='tab _tab '> <a href="#" class="stab _a" onclick="return tCR('u=javascript&r=&i=&a=shp_gui*m.tab&g=maker_3675');"> <span class="dot"></span> <span class="name" title="삼성전자">삼성전자</span> <span class="spshop ico_arr">선택됨</span> </a> </li>  ...
#         var _elAdIndLayerBz = null;
#         var _elAdIndLayerTimeBz;
#         var _elDscNcautionBz = null;
#
#         function adInfoShowBz(el) {
#             if (_elAdIndLayerBz) {
#                 adInfoHideBz();
#                 return false;
#             } else {
#                 if (!_elDscNcautionBz) {
#                     _elDscNcautionBz = $Element(el).parent();
#                 }
#                 _elDscNcautionBz._element.style.zIndex = 121;
#                 _elAdIndLayerBz = $Element(el).next();
#                 _elAdIndLayerBz.show();
#                 _elAdIndLayerTimeBz = (new Date()).getTime();
#                 return true;
#             }
#         }
#
#         function adInfoHideBz() {
#             if (_elAdIndLayerBz) {
#                 if (_elDscNcautionBz) {
#                     _elDscNcautionBz._element.style.zIndex = 0;
#                 }
#                 _elAdIndLayerBz.hide();
#                 _elAdIndLayerBz = null;
#             }
#         }
#
#         function adInfoHideClickEventHandlerBz(e) {
#             if (_elAdIndLayerTimeBz + 200 < (new Date()).getTime()) adInfoHideBz();
#         }
#
#         document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerBz, false);
#     </script>
#     <div class="ad_section section _bz_section bg_type_v2">
#         <div class="section_head"><h2>비즈사이트</h2>
#             <div class="dsc_ncaution">
#               <span><em class="dsc_ncaution_quotation">&lsquo;</em><strong class="dsc_ncaution_keyword">에어컨</strong><em class="dsc_ncaution_quotation">&rsquo;</em></span>
#               <span class="dsc_ncaution_text">관련 광고입니다.</span>
#                 <a class="ico_ad_dsc" href="javascript:void(0);" title="이 광고가 표시된 이유" onclick="if(adInfoShowBz(this)) goOtherCR(this, &#39;a=biz_nop.adset&amp;r=0&amp;i=biz_nopadset&amp;u=&#39;+urlencode(this.href));">이 광고가 표시된 이유</a>
#                 <div class="ly_ad_dsc" onclick="adInfoHideBz();" style="display:none"><span class="ico_arr">&nbsp;</span>
#                     <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
#                     <button class="bt_ad_clse" title="안내 레이어 닫기" type="button">안내 레이어 닫기</button>
#                 </div>
#             </div>
#             <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" target="_blank" onclick="return goOtherCR(this, &#39;a=biz_nop.registration&amp;r=0&amp;i=biz_nopregistration&amp;u=&#39;+urlencode(this.href));">등록 안내</a></div>
#         <div class="ad_area nx_power" id="biz_site_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=JxTfYKnj7J1Wxr6UeUKGpMy7zEMPN_...">
#             <ul class="lst_type ">
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="0" class="lst lst1">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=x5mfSjH5J9UzNfDUeD3HA////w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=1&amp;i=nad-a001-01-000000026945550&amp;d=&#39; + urlencode(&#39;http://smartstore.naver.com/airconeworld&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">캐리어 에어컨 남인천총판</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=x5mfSjH5J9UzNfDUeD3HA////w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=1&amp;i=nad-a001-01-000000026945550&amp;d=&#39;+urlencode(&#39;http://smartstore.naver.com/airconeworld&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">smartstore.naver.com/airconeworld</a>
#             <span class="ico_area">
#               <span class="ico">
#                 <span alt="네이버페이" class="sp_ad ico_npay" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
#                 <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank" onclick="return goOtherCR(this, &#39;a=biz_nop.checkout&amp;r=1&amp;i=nad-a001-01-000000026945550&amp;u=&#39;+urlencode(this.href));">
#                   <span class="ly_box">
#                     <p>네이버 아이디 하나로 간편구매</p>
#                     <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
#                   </span>
#                     <span class="sp_ad ly_tail"></span>
#                 </a>
#               </span>
#
#               <span class="ico">
#                 <span class="sp_ad ico_talktalk" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 톡톡</span>
#                 <a class="ly_ad _tooltip" href="//talk.naver.com/intro" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank" onclick="return goOtherCR(this, &#39;a=biz_nop.talktalk&amp;r=1&amp;i=nad-a001-01-000000026945550&amp;u=&#39;+urlencode(this.href));">
#                   <span class="ly_box">
#                     <p>네이버톡톡으로 상담이 가능한 사이트입니다.</p>
#                     <p class="ly_ad_go"><strong>톡톡</strong> 서비스 보기<span class="sp_ad bu"></span></p>
#                   </span>
#                     <span class="sp_ad ly_tail"></span>
#                 </a>
#               </span>
#
#             </span>
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=x5mfSjH5J9UzNfDUeD3HA////w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=1&amp;i=nad-a001-01-000000026945550&amp;d=&#39;+urlencode(&#39;http://smartstore.naver.com/airconeworld&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 30년 전통 케리어<strong class='hl'>에어컨</strong> 도매소매 전문점,캐리어 공식인증전문점.세금계산서,카드환영
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="1" class="lst lst2">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=GiHcMBu2jDt30laVab4wIP///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=2&amp;i=nad-a001-01-000000046468706&amp;d=&#39; + urlencode(&#39;http://www.enuri.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">에어컨 에누리 가격비교</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=GiHcMBu2jDt30laVab4wIP///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=2&amp;i=nad-a001-01-000000046468706&amp;d=&#39;+urlencode(&#39;http://www.enuri.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.enuri.com</a>
#             <span class="ico_area">
#
#               <span class="ico">
#                 <span class="sp_ad ico_nlogin" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);">네이버 로그인</span>
#                 <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onBlur="NAVER.SEARCH_AD.hideTooltip(this);" onFocus="NAVER.SEARCH_AD.showTooltip(this);" onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onMouseOver="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" onclick="return goOtherCR(this, &#39;a=biz_nop.naverlogin&amp;r=2&amp;i=nad-a001-01-000000046468706&amp;u=&#39;+urlencode(this.href));">
#                   <span class="ly_box">
#                     <p>네이버 아이디로 로그인이 가능합니다.</p>
#                     <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
#                   </span>
#                     <span class="sp_ad ly_tail"></span>
#                 </a>
#               </span>
#
#
#             </span>
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=GiHcMBu2jDt30laVab4wIP///w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=2&amp;i=nad-a001-01-000000046468706&amp;d=&#39;+urlencode(&#39;http://www.enuri.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 에누리 찍고 구매시 8.3% 추가할인! 앱 구매시 e머니 추가적립! <strong class='hl'>에어컨</strong>
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="2" class="lst lst3">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=Bak+IQ8iJL4xbBBIcedYiv///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=3&amp;i=nad-a001-01-000000049859838&amp;d=&#39; + urlencode(&#39;http://www.lottesuper.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">롯데슈퍼의 새이름 롯데프레시</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=Bak+IQ8iJL4xbBBIcedYiv///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=3&amp;i=nad-a001-01-000000049859838&amp;d=&#39;+urlencode(&#39;http://www.lottesuper.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.lottesuper.co.kr</a>
#
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=Bak+IQ8iJL4xbBBIcedYiv///w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=3&amp;i=nad-a001-01-000000049859838&amp;d=&#39;+urlencode(&#39;http://www.lottesuper.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 <strong class='hl'>에어컨</strong>, 첫구매고객은 신라면 100원! 간편하고 빠르게 3시간내 슈퍼배송!
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="3" class="lst lst4">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=5Az7WG06moPDvzfC0n3lc////w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=4&amp;i=nad-a001-01-000000045077681&amp;d=&#39; + urlencode(&#39;http://www.wemakeprice.com/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">위메프 에어컨</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=5Az7WG06moPDvzfC0n3lc////w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=4&amp;i=nad-a001-01-000000045077681&amp;d=&#39;+urlencode(&#39;http://www.wemakeprice.com/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.wemakeprice.com/</a>
#
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=5Az7WG06moPDvzfC0n3lc////w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=4&amp;i=nad-a001-01-000000045077681&amp;d=&#39;+urlencode(&#39;http://www.wemakeprice.com/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 위메프 디지털폭격! 최대 16% 더블 할인! 쿠폰+카드사 혜택 <strong class='hl'>에어컨</strong>
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#                 <li onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');" num="4" class="lst lst5">
#                     <div class="inner">
#                         <a class="lnk_tit" target="_blank" href="https://adcr.naver.com/adcr?x=1Xv0c9BnHSfOQVddWKmXVf///w==...&amp;p=0" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=5&amp;i=nad-a001-01-000000013382956&amp;d=&#39; + urlencode(&#39;http://www.리셋크린.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">에어컨완전분해청소 은빛클리닝</a>
#
#                         <a class="lnk_url" target="_blank" href="https://adcr.naver.com/adcr?x=1Xv0c9BnHSfOQVddWKmXVf///w==...&amp;p=1" onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000013382956&amp;d=&#39;+urlencode(&#39;http://www.리셋크린.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.리셋크린.com</a>
#
#                         <div class="dsc_area">
#                             <a class="ad_dsc" target="_blank" title="새 창으로 이동" href="https://adcr.naver.com/adcr?x=1Xv0c9BnHSfOQVddWKmXVf///w==...&amp;p=2" onclick="return goOtherCR(this, &#39;a=biz_nop.description&amp;r=5&amp;i=nad-a001-01-000000013382956&amp;d=&#39;+urlencode(&#39;http://www.리셋크린.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                                 100%<strong class='hl'>에어컨</strong>분해청소 벽걸이형 슬림형 천정형, 세균 곰팡이 악취제거 A/S보장
#
#                             </a>
#                         </div>
#
#                     </div>
#                 </li>
#             </ul>
#         </div>
#
#         <div class="ad_banner">
#             <span class="sp_ad ico_npay">네이버페이</span>마크는 네이버ID로 편리하고 안전하게 구매할 수 있는 네이버페이 사용처에 표시됩니다.<br />
#             네이버페이 사용처에서 구매하시면 네이버페이 포인트를 적립해드립니다.
#             <a class="more_mileage" href="//event2.pay.naver.com/event/benefit/list?frm=sa" onclick="return goOtherCR(this, 'a=mib_biz.banner&r=0&i=mib_bizbanner&u='+urlencode(this.href));" target="_blank">혜택 자세히 보기</a>
#         </div>
#         <div class="section_more">
#             <a class="go_site" target="_blank" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%97%90%EC%96%B4%EC%BB%A8&amp;referenceId=U5PK1dpVuFZssu7r%2FShssssssGG-113508&amp;bucket=0" onclick="return goOtherCR(this, &#39;a=biz_nop.more&amp;r=1&amp;i=bizmore&amp;u=&#39;+urlencode(this.href));">더보기</a>
#         </div>
#     </div><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_kindic_180830.css"> <script type="text/javascript"> function wiki_escape(url) { if (navigator.appName.charAt(0) == "M" && navigator.appVersion.indexOf("MSIE 6") != -1) { tmp = escape(url); ret = tmp.replace("http\%3A", "http:"); } else if (navigator.appName.indexOf("Opera") != -1) { len = url.length; last_pos = url.lastIndexOf("/"); url_prefix = url.substr(0, last_pos + 1); url_item = url.substr(last_pos + 1, len - last_pos); ret = url_prefix + (encodeURIComponent(url_item)); } else ret = url; return ret; } </script> <div class="sp_kindic sc _sp_kindic"> <div class="sc_head"> <h2>지식백과</h2> </div> <div class="sc_kindic"> <div class="group_kindic type_attach"> <div class="kindic"> <div class="thumb_area " id="kdic_thumb_1"> <a target="_blank" href="https://terms.naver.com/entry.nhn?docId=1063140&cid=40942&categoryId=32351" class="link_thumb" onclick="return goOtherCR(this,'a=kdc_gnl*D.thumb&r=1&i=88000010_000000000000000000003e20&u='+urlencode(this.href));"> <img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F2765_000_2%2F20151118181647978_0II11U6QM.gif%2F15904_0.gif%3Ftype%3Dw450_fst%23450x314&type=mfullfill160_160" onload="this.parentNode.className='link_thumb';" onerror="this.parentNode.style.display='none';" width="80" height="80" class="thumb" alt=""><span class="thumb_bd"></span></a> </div> <div class="info_area"> <div class="tit_box"> <a target="_blank" href="https://terms.naver.com/entry.nhn?docId=1063140&cid=40942&categoryId=32351" class="tit type_dsc" onclick="return goOtherCR(this,'a=kdc_gnl*D.title&r=1&i=88000010_000000000000000000003e20&u='+urlencode(this.href));"> <strong>에어컨</strong> </a> <a target="_blank" href="https://terms.naver.com/entry.nhn?docId=1063140&cid=40942&categoryId=32351" class="dsc" onclick="return goOtherCR(this,'a=kdc_gnl*D.title&r=1&i=88000010_000000000000000000003e20&u='+urlencode(this.href));">실내온도를 낮추거나 쾌적한 상태로 유지하게 하는 기계장치</a> </div> <p class="txt_box"> 실내온도를 낮추거나 쾌적한 상태로 유지하게 하는 기계장치. 여름에 주로 이용하기 때문에 냉방장치(冷房裝置)라고도 부른다. 일정한 공간을 인간이 활동하기에... </p> <div class="source_box"><span class="source">두산백과</span><span class="source"><a href="https://terms.naver.com/list.nhn?cid=40942&categoryId=32350" target="_blank" title="지식백과 색인 목록" onclick="return goOtherCR(this,'a=kdc_gnl*D.category&r=1&i=88000010_000000000000000000003e20&u='+urlencode(this.href));">기계공학</a> &gt; <a href="https://terms.naver.com/list.nhn?cid=40942&categoryId=32351" target="_blank" title="지식백과 색인 목록" onclick="return goOtherCR(this,'a=kdc_gnl*D.category&r=1&i=88000010_000000000000000000003e20&u='+urlencode(this.href));">기계공학일반</a></span> </div> </div> </div> <div class="kindic"> <div class="thumb_area " id="kdic_thumb_2"> <a target="_blank" href="https://terms.naver.com/entry.nhn?docId=2464260&cid=51399&categoryId=51399" class="link_thumb" onclick="return goOtherCR(this,'a=kdc_gnl*K.thumb&r=2&i=8814ccb9_000000005fbc014bfd26a3a4&u='+urlencode(this.href));"> <img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3745_000_4%2F20150319101355741_9QNRTSUE1.jpg%2Ffh2_55002848_i1.jpg%3Ftype%3Dw450_fst%23170x170%23c170&type=n_mfullfill160_160" onload="this.parentNode.className='link_thumb';" onerror="this.parentNode.style.display='none';" width="80" height="80" class="thumb" alt=""><span class="thumb_bd"></span></a> </div> <div class="info_area"> <div class="tit_box"> <a target="_blank" href="https://terms.naver.com/entry.nhn?docId=2464260&cid=51399&categoryId=51399" class="tit " onclick="return goOtherCR(this,'a=kdc_gnl*K.title&r=2&i=8814ccb9_000000005fbc014bfd26a3a4&u='+urlencode(this.href));"> <strong>에어컨</strong> </a> </div> <p class="txt_box">제품에 따라 난방이 가능한 제품은 겨울철 히터로도 사용할 수 있습니다. 제품에 따라 공기청정, 습기제거, 가습기능 등 다양한 기능이 있습니다. <strong>에어컨</strong></p> <div class="source_box"><span class="source">쇼핑용어사전</span><span class="source"><a href="https://terms.naver.com/l ...
#
#
#  <script type="text/javascript"> /* thumnail 처리 */ function on_realtime_nxtab_noimage(img, type ) { img.onerror=null; img.src="https://ssl.pstatic.net/sstatic/search/img3/img_profile_twitter5.png"; img.alt="이미지 준비중"; img.width="50"; img.height="50"; } </script> <div class="realtime2 section _prs_rea_doc" id="realTimeSearchBody"> <div class="section_head"> <h2>실시간검색</h2> <a href="https://help.naver.com/support/alias/search/integration/integration_7.naver" target="_blank" class="link_help" onclick="return goOtherCR(this, 'a=rea.help&r=0&i=0&u='+urlencode(this.href));"><i class="sprenew api_ico_help">도움말</i></a> <p class="title_desc sort"> <strong>최신</strong> <span class="bar"></span> <a href="?where=realtime&sm=tab_smr&query=%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&best=1" onclick="return goOtherCR(this, 'a=rea.pop&r=0&i=0&u='+urlencode(this.href));" >인기</a> </p> <div class="rt_update"><span class="update_state"></span></div> </div> <h3 class="blind">최신순</h3> <div class="rt_wrap rt_wrap2"> <div> <ul class="type01"> <li class="first_child"> <div class="thumb"> <a href="http://sports.news.naver.com/comment/pass.nhn?ticket=sports&amp;objectId=news529,0000032096&amp;type=commentList" target="_blank" crlink="a=rea_doc*s.img&r=&i=9015809d_00000001000000000B2D4502&ps=&nd=&u=" ><img src="https://ssl.pstatic.net/sstatic/search/2015/ico_rt_sports.png" width="50" height="50" alt="스포츠 댓글"> <span class="mask"></span> <span class="valign"></span> </a> </div> <dl> <dd> <a href="http://sports.news.naver.com/comment/pass.nhn?ticket=sports&amp;objectId=news529,0000032096&amp;type=commentList" class="rt_user" target="_blank" crlink="a=rea_doc*s.id&r=&i=9015809d_00000001000000000B2D4502&ps=&nd=&u=" ><span class="user_name">스마일</span></a> </dd> <dd><a href="http://sports.news.naver.com/comment/pass.nhn?ticket=sports&amp;objectId=news529,0000032096&amp;type=commentList" class="txt_link" target="_blank" crlink="a=rea_doc*s.comment&r=&i=9015809d_00000001000000000B2D4502&ps=&nd=&u=" >FA 김시래.김종규 걱정이네.샐러리캡돈 모자라면 어덯게 하지.엘지전자 광고모텔로 충당 하는 거 고려 해 볼만.예전에 인삼공사에서 비슷하게 한거 같은데.김시래 23m 버저비터 영상과 김시래 엘리엇 패스를 받아 김종규 투핸드덩크쑷.휘센 <strong class="hl">에어컨</strong> 마냥 시원하고.특히,LG창원공장 생산품 세계적 호평 받고 있으니 글로벌 광고 보내는 것도 괜찮아 보이는데</a></dd> <dd class="rt_sub _rt_time _time_1553435198"> <div class="sub_area"> <span class="sub_time _timeinfo">11분 전</span> <span class="bar"></span> <span class="sub_reply">답글 0</span> <span class="bar"></span> <span class="sub_like ">공감 0</span> <span class="bar"></span> <span class="sub_dis">비공감 0</span> </div> </dd> <dd class="rt_org"> <div class="org_area"> <a href="http://sports.news.naver.com/comment/pass.nhn?ticket=sports&amp;objectId=news529,0000032096" class="org_thumb" target="_blank" crlink="a=rea_doc*s.source&r=&i=9015809d_00000001000000000B2D4502&ps=&nd=&u=" ><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Fthumb154%2F529%2F2019%2F03%2F24%2F32096.jpg&type=n66_66_re2" width="30" height="30" alt="[엠스플 KBL] 24득점 폭발 김종규 “연습 때처럼 던지니 쏙쏙 들어가더라”" onerror="this.parentNode.style.display='none';"> <span class="mask"></span> <span class="valign"></span></a> <div class="org_info"> <a href="http://sports.news.naver.com/comment/pass.nhn?ticket=sports&amp;objectId=news529,0000032096" class="info_tit" target="_blank" crlink="a=rea_doc*s.source&r=&i=9015809d_00000001000000000B2D4502&ps=&nd=&u=" >[엠스플 KBL] 24득점 폭발 김종규 “연습 때처럼 던지니 쏙쏙 들어가더라”</a> <a href="http://sports.news.naver.com/comment/pass.nhn?ticket=sports&amp;objectId=news529,0000032096" class="info_cite" target="_blank" crlink="a=rea_doc*s.source&r=&i=9015809d_00000001000000000B2D4502&ps=&nd=&u=" ><cite>sports.news.naver.com</cite></a> </div> </div> </dd></dl> </li> <li class="rt_mt "> <div class="thumb"> <a target="_blank" href="https://twitter.com/Blue_cat_1995" crlink="a=rea_doc*t.img&r=&i=a00000fa_559c525847da7aa6d156b8b5&ps=&nd=&u=" ><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fpbs.twimg.com%2Fprofile_images%2F1097825504999071744%2FRWrECly0_big ...
# <div class="collection"></div> </div><div id="sub_pack" class="sub_pack"><a href="https://alpha.naver.com/experiment/newnaverapp/beta?id=srh" target="_blank" onclick="return goOtherCR(this, 'a=bnr.link&r=&i=&u='+urlencode(this.href));" class="api_banner" style="background-color:#fff;"><img src="https://ssl.pstatic.net/sstatic/search/pc/tmp/ban_app_v3.png" width="400" height="60" class="img" alt="이제 iOS에서도 ‘새로운 네이버’를 경험해 보세요 이용방법 보기"></a><div class="z_aside section rktshp"> <div class="section_head"> <h2>에어컨/냉방기 쇼핑검색어</h2> </div> <div class="realtime_srch"> <ol class="lst_realtime_srch"> <li> <a href="?query=%EB%B2%BD%EA%B1%B8%EC%9D%B4%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="벽걸이에어컨" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=1')"> <span class="keyword"> <em class="num">1</em> <span class="tit">벽걸이에어컨</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">1</span></em> </a> </li> <li> <a href="?query=%ED%9C%B4%EB%8C%80%EC%9A%A9%EC%84%A0%ED%92%8D%EA%B8%B0&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="휴대용선풍기" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=2')"> <span class="keyword"> <em class="num">2</em> <span class="tit">휴대용선풍기</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">1</span></em> </a> </li> <li> <a href="?query=2IN1%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="2IN1에어컨" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=3')"> <span class="keyword"> <em class="num">3</em> <span class="tit">2IN1에어컨</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">1</span></em> </a> </li> <li> <a href="?query=%EC%82%BC%EC%84%B1%EB%AC%B4%ED%92%8D%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="삼성무풍에어컨" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=4')"> <span class="keyword"> <em class="num">4</em> <span class="tit">삼성무풍에어컨</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">5</span></em> </a> </li> <li> <a href="?query=LG%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="LG에어컨" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=5')"> <span class="keyword"> <em class="num">5</em> <span class="tit">LG에어컨</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">1</span></em> </a> </li> <li> <a href="?query=%EC%82%BC%EC%84%B1%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="삼성에어컨" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=6')"> <span class="keyword"> <em class="num">6</em> <span class="tit">삼성에어컨</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">2</span></em> </a> </li> <li> <a href="?query=%EC%BA%90%EB%A6%AC%EC%96%B4%EC%97%90%EC%96%B4%EC%BB%A8&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="캐리어에어컨" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=7')"> <span class="keyword"> <em class="num">7</em> <span class="tit">캐리어에어컨</span> </span> <em class="rank up"><span class="spim">상승</span><span class="count">3</span></em> </a> </li> <li> <a href="?query=LG%EC%97%90%EC%96%B4%EC%BB%A82IN1&ie=utf8&sm=tab_shk&rm=058k%2Cnexearch%2Csearch_all%2C0" class="bx bx_item" title="LG에어컨2IN1" onclick="return goOtherCR(this, 'u='+urlencode(urlexpand(this.href))+'&amp;a=shk_058.list&amp;i=&amp;r=8')"> <span class="keywor ...
