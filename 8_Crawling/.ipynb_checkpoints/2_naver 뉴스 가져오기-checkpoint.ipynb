# %%
from urllib.request import urlopen 
import bs4
import datetime

# %%
url = "https://news.naver.com/"

html = urlopen(url)

# %%
bs_obj=bs4.BeautifulSoup(html.read(), "html.parser")

# %%
print(bs_obj)
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="http://news.naver.com/main/home.nhn" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" property="og:image">
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" name="twitter:image"/>
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
# <title>네이버 뉴스</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20190321_154734/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20190321_154734/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20190321_154734/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20190321_154734/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# document.domain='naver.com';
# var _MAIN_NEWS_MENU_ID='home';
# var _MAIN_NEWS_SECTION_ID='100';
# var ccsrv='cc.naver.com';
# var g_ssc='news.home';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout='https://news.naver.com';
# var gnb_template='gnb_utf8';
# var gnb_brightness = 1;
# var gnb_one_naver = 1;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Sat Mar 23 14:16:31 KST 2019";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20190321_154734/js/news.service.js" type="text/javascript"></script>
# </meta></meta></meta></meta></head>
# <body>
# <div id="wrap">
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_wrap">
# <!-- GNB 마크업 -->
# <div id="gnb"></div>
# <!-- //GNB 마크업 -->
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(STA.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(STA.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="nclicks(STA.enter)" href="https://entertain.naver.com/home"><img alt="TV연예" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_entertain.png" width="52"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.sports)" href="https://sports.news.naver.com"><img alt="스포츠" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_sports.png" width="48"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.newsstand)" href="https://newsstand.naver.com"><img alt="뉴스스탠드" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_newsstand.png" width="77"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.weather)" href="https://weather.naver.com"><img alt="날씨" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_weather.png" width="31"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li class="lnb_menu_home on"><a class="nclicks(LNB.home)" href="/main/home.nhn"><span class="tx">뉴스홈</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(LNB.flash)" href="/main/list.nhn?mode=LSD&amp;mid=sec&amp;sid1=001"><span class="tx">속보</span></a></li>
# <li><a class="nclicks(LNB.pol)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li><a class="nclicks(LNB.eco)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(LNB.soc)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(LNB.lif)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(LNB.wor)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(LNB.sci)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(LNB.opi)" href="/main/opinion/home.nhn"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(LNB.pho)" href="/main/photo/index.nhn?mid=pho"><span class="tx">포토</span> </a></li>
# <li><a class="nclicks(LNB.tv)" href="/main/tv/index.nhn?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(LNB.ranking)" href="/main/ranking/popularDay.nhn?mid=etc&amp;sid1=111"><span class="tx">랭킹뉴스</span> </a></li>
# </ul>
# <form accept-charset="UTF-8" action="https://search.naver.com/search.naver" id="lnb.searchForm" method="get" name="lnb_searchForm" target="_blank">
# <fieldset>
# <legend>뉴스 검색</legend>
# <input accesskey="s" class="text_index" name="query" style="ime-mode:active;" title="뉴스 검색" type="text"/>
# <input name="where" type="hidden" value="news"/>
# <input name="ie" type="hidden" value="utf8"/>
# <input name="sm" type="hidden" value="nws_hty"/>
# <button class="btn_search_lnb nclicks(LNB.search)" type="submit"><span class="tx"><span class="blind">검색</span></span></button>
# </fieldset>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="home_timelate">
# <div class="ht_head">
# <ul class="ht_tabmnu">
# <li id="ht_tabmnu_0">
# <a href="#" title="신문 헤드라인">신문 헤드라인<span class="ht_ico"></span></a>
# </li>
# <li id="ht_tabmnu_1">
# <a href="#" title="저녁 방송 뉴스">저녁 방송 뉴스<span class="ht_ico"></span></a>
# </li>
# </ul>
# <ul class="lnb_side" tabindex="0">
# <li>
# <a class="nclicks(nct.right1)" href="https://news.naver.com/main/factcheck/main.nhn" title="팩트체크">팩트체크
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right2)" href="https://news.naver.com/main/officeList.nhn" title="언론사 뉴스">언론사 뉴스
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right3)" href="https://m.news.naver.com/hotissue/main.nhn?sid1=110&amp;cid=1083360" target="_blank" title="구독 이벤트">구독 이벤트
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리
# </a>
# </li>
# <li class="end">
# <a class="nclicks(nct.right5)" href="https://news.naver.com/main/history/mainnews/index.nhn" title="이 시각 주요뉴스 배열 이력">기사배열 이력
# </a>
# </li>
# </ul>
# </div>
# <div class="ht_comp ht_paperheadline" id="paperHeadlineRolling" style="display: none;">
# <h3 class="blind">신문 헤드라인</h3>
# <ul class="ht_ph_lst" style="display: none;">
# <!-- 헤드라인 데이터 동적삽입 <li> -->
# </ul>
# <div class="ht_nodata_all" style="display: none;">발행된 종이신문이 없거나 신문게재 정보가 입력되지 않았습니다.</div>
# <div class="ht_navi">
# <a class="ht_btn_prev nclicks(opt.prev)" href="javascript:;"><span class="ht_ico"></span><span class="blind">이전</span></a>
# <a class="ht_btn_next nclicks(opt.next)" href="javascript:;"><span class="ht_ico"></span><span class="blind">다음</span></a>
# <a class="ht_btn_fold nclicks(opt.open)" href="javascript:;"><span class="ht_btn_box"><span class="ht_btn_ico"></span><span class="blind">접기</span></span></a>
# </div>
# </div>
# <div class="ht_comp ht_eveningnews" id="eveningNewsRolling" style="display: none;">
# <h3 class="blind">저녁 방송 뉴스</h3>
# <ul class="ht_ph_lst">
# <!-- 저녁방송뉴스 동적삽입 <li> -->
# </ul>
# <div class="ht_navi">
# <a class="ht_btn_prev nclicks(opt.prev);" href="javascript:;"><span class="ht_ico"></span><span class="blind">이전</span></a>
# <a class="ht_btn_next nclicks(opt.next)" href="javascript:;"><span class="ht_ico"></span><span class="blind">다음</span></a>
# <a class="ht_btn_fold nclicks(opt.open)" href="javascript:;"><span class="ht_btn_box"><span class="ht_btn_ico"></span><span class="blind">접기</span></span></a>
# </div>
# </div>
# <script type="text/javascript">
# _oTopComponentData = {
# "open" : "N",
# "target" : "headlineList",
# "headlineList" : [
# {
# "officeId" : "008",
# "officeName" : "머니투데이",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/008/2017/01/05/logo_008_1_20170105110505.gif' width='206' height='30' alt='머니투데이' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "044",
# "officeName" : "코리아헤럴드",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/044/2017/01/05/logo_044_1_20170105110505.gif' width='206' height='30' alt='코리아헤럴드' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "009",
# "officeName" : "매일경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/009/2017/01/05/logo_009_1_20170105110505.gif' width='206' height='30' alt='매일경제' title='' class='' >",
# "thumbnail" : "",
# "title" : "북한, 개성 연락사무소 돌연 철수",
# "summary" : "北, 美 추가제재하자 `돌변` 靑, NSC긴급소집 대책 논의 정부 \"北 조속히 복귀 희망\" 미국이 하노이 미·북 정상회담 결렬 이후 3주 만에 대북 독자 제재에 나서자 북한은 22일 개성 남북 공동연락사무소에 상주하",
# "publishDate" : "20190323"
# },
# {
# "officeId" : "081",
# "officeName" : "서울신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/081/2017/01/05/logo_081_1_20170105110505.gif' width='206' height='30' alt='서울신문' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "022",
# "officeName" : "세계일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/022/2017/01/05/logo_022_1_20170105110505.gif' width='206' height='30' alt='세계일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/022/2019/03/22/3348802.jpg?type=nf80_54",
# "title" : "北, 개성연락사무소 철수…한·미 동시 겨냥 불만 표시 [뉴스분석]",
# "summary" : "北 “상부 지시에 따른 것” 통보/ 靑, 정의용 주재 긴급 NSC 개최/ 美, 올 들어 첫 대북 독자제재 실시/ 中해운사 2곳 제재·韓선박 주의보 북한이 22일 남북공동연락사무소에서 철수한다고 밝혔다. 사진은 201",
# "publishDate" : "20190323"
# },
# {
# "officeId" : "014",
# "officeName" : "파이낸셜뉴스",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/014/2017/01/05/logo_014_1_20170105110505.gif' width='206' height='30' alt='파이낸셜뉴스' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/014/2019/03/22/4198149.jpg?type=nf80_54",
# "title" : "회계감사 \'매의 눈\' 대기업도 못피했다",
# "summary" : "대기업도 \'죽음의 계절\'인 감사시즌을 피해가지 못했다. 코스닥 상장사들에만 매섭게 느껴졌던 \'감사 한파\'가 대기업에도 불어닥치며 상장사는 물론 투자자들도 충격에 빠졌다. 올해 새로 적용된 \'신외감법(주식회사 등의 외",
# "publishDate" : "20190323"
# },
# {
# "officeId" : "023",
# "officeName" : "조선일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/023/2017/01/05/logo_023_1_20170105110505.gif' width='206' height='30' alt='조선일보' title='' class='' >",
# "thumbnail" : "",
# "title" : "\'환경부 블랙리스트\' 김은경 前장관 영장",
# "summary" : "검찰, 文정부 장관에 첫 청구 前정권때 임명된 임원들에게 사표 종용 등 직권남용 혐의 \'환경부 블랙리스트\' 사건을 수사 중인 검찰이 22일 김은경<사진> 전 환경부 장관에 대해 구속영장을 청구했다. 이 사건 수사에 ",
# "publishDate" : "20190323"
# },
# {
# "officeId" : "005",
# "officeName" : "국민일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/005/2017/01/05/logo_005_1_20170105110505.gif' width='206' height='30' alt='국민일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/005/2019/03/23/1183869.jpg?type=nf80_54",
# "title" : "“사이다” 환호… 대중의 이중잣대가 정치인 막말 부추긴다",
# "summary" : "자유한국당 의원들의 이른바 ‘5·18 망언 퍼레이드’에 이어 문재인 대통령을 ‘김정은 (북한 국무위원장의) 수석대변인’에 빗댄 나경원(사진) 자유한국당 원내대표의 국회연설 이후 막말 정치에 대한 비판이 한창이다. 여",
# "publishDate" : "20190323"
# },
# {
# "officeId" : "011",
# "officeName" : "서울경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/011/2017/01/05/logo_011_1_20170105110505.gif' width='206' height='30' alt='서울경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/011/2019/03/22/3525539.jpg?type=nf80_54",
# "title" : "보신주의 회계감사에 떠는 기업들",
# "summary" : "[서울경제] 대기업 가운데 이례적으로 아시아나항공이 감사의견 ‘한정’을 받으면서 대기업·중소기업 가릴 것 없이 ‘감사 리스크’ 공포가 확산되고 있다. 올해부터 외부감사에 관한 법률이 강화돼 회계법인들이 깐깐하게 감사",
# "publishDate" : "20190323"
# },
# {
# "officeId" : "025",
# "officeName" : "중앙일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/025/2018/08/03/logo_025_1_20180803103703.jpg' width='206' height='30' alt='중앙일보' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "018",
# "officeName" : "이데일리",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/018/2017/01/05/logo_018_1_20170105110505.gif' width='206' height='30' alt='이데일리' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "015",
# "officeName" : "한국경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/015/2017/01/05/logo_015_1_20170105110505.gif' width='206' height='30' alt='한국경제' title='' class='' >",
# "thumbnail" : "",
# "title" : "檢 \'환경부 블랙리스트\' 김은경 前장관 구속영장 청구",
# "summary" : "박근혜 정권 인사 표적 물갈이 혐의 [ 정의진 기자 ] ‘환경부 블랙리스트’ 의혹을 수사 중인 검찰이 22일 김은경 전 환경부 장관의 구속영장을 청구했다. 박근혜 정부에서 임명된 환경부 산하기관 임직원을 표적 감사해",
# "publishDate" : "20190323"
# },
# {
# "officeId" : "028",
# "officeName" : "한겨레",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/028/2017/01/05/logo_028_1_20170105110505.gif' width='206' height='30' alt='한겨레' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/028/2019/03/22/2447518.jpg?type=nf80_54",
# "title" : " 북, 개성 남북연락사무소 전원 철수…고강도 대남 압박 ",
# "summary" : "뉴스 분석 연락대표 통해 “상부 지시” 통보 ‘하노이 무산’ 여파 남북관계로 번져 미국 고강도 제재에 우회 반발 ‘북, 남북경협 이행 촉구 의미’ 해석 정부, NSC 상임위…“정상운영 희망” 남, 계속 잔류…북, 군",
# "publishDate" : "20190323"
# },
# {
# "officeId" : "016",
# "officeName" : "헤럴드경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/016/2017/01/05/logo_016_1_20170105110505.gif' width='206' height='30' alt='헤럴드경제' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "029",
# "officeName" : "디지털타임스",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/029/2018/07/18/logo_029_1_20180718140618.jpg' width='206' height='30' alt='디지털타임스' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "353",
# "officeName" : "중앙SUNDAY",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/353/2018/03/17/logo_353_1_20180317103917.png' width='206' height='30' alt='중앙SUNDAY' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/353/2019/03/23/33616.jpg?type=nf80_54",
# "title" : "북, 연락사무소 철수…한반도 ‘3월의 겨울’",
# "summary" : "━ 뉴스분석 북한이 22일 개성공단 내 남북공동연락사무소(이하 연락사무소)에서 일방적으로 철수했다. 문을 연지 189일 만이다. 북한은 이날 오전 9시 15분쯤 연락사무소 남북 연락대표 간 접촉을 통해 “북측 연락사",
# "publishDate" : "20190323"
# },
# {
# "officeId" : "277",
# "officeName" : "아시아경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/277/2017/01/05/logo_277_1_20170105110505.gif' width='206' height='30' alt='아시아경제' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "021",
# "officeName" : "문화일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/021/2017/01/05/logo_021_1_20170105110505.gif' width='206' height='30' alt='문화일보' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "469",
# "officeName" : "한국일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/469/2018/01/26/logo_469_1_20180126174326.gif' width='206' height='30' alt='한국일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/469/2019/03/23/374327.jpg?type=nf80_54",
# "title" : "미국 제재 고삐ㆍ북한 개성 철수 ‘한반도의 봄’ 급랭",
# "summary" : "美 하노이 노딜 후 첫 대북제재한 날, 北 개성 연락사무소 철수 정부 “유감, 조속 복귀를” 北, 美에 “언제든 판 깰 수 있다” 신호 북한이 22일 개성 남북공동연락사무소에서 일방적으로 철수했다. 개성 연락사무소는",
# "publishDate" : "20190323"
# },
# {
# "officeId" : "020",
# "officeName" : "동아일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/020/2017/01/05/logo_020_1_20170105110505.gif' width='206' height='30' alt='동아일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/020/2019/03/23/3206193.jpg?type=nf80_54",
# "title" : "北에 얻어맞고 美경고 받고 ‘샌드위치 한국’",
# "summary" : "北, 개성 남북연락사무소 일방 철수… 정부 “유감” 美와 대치속 남북 판문점 합의로 만든 대화 채널 닫아 靑, NSC 상임위 열어 대책 논의… 별도 입장 발표 안해 北 “핵단추 누를지 말지” 최선희 발언 공개하며 美",
# "publishDate" : "20190323"
# },
# {
# "officeId" : "032",
# "officeName" : "경향신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/032/2017/01/05/logo_032_1_20170105110505.gif' width='206' height='30' alt='경향신문' title='' class='' >",
# "thumbnail" : "",
# "title" : "북, 개성 남북연락사무소 인력 전원 철수",
# "summary" : "ㆍ“상부 지시” 어제 일방 통보…통일부 “유감, 조속 복귀를” 촉구 ㆍ남북간 상시 소통채널 닫혀…이산가족 화상상봉 등 차질 예상 북한이 22일 개성 남북공동연락사무소에서 북측 인원들을 전원 철수시켰다. 2차 북·미 ",
# "publishDate" : "20190323"
# },
# {
# "officeId" : "030",
# "officeName" : "전자신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/030/2017/01/05/logo_030_1_20170105110505.gif' width='206' height='30' alt='전자신문' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# }
# ]
# ,
# "liveTvList" : [
# {
# "officeId" : "422",
# "articleId" : "0000366815",
# "sectionId" : "74f",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/422/2018/01/10/logo_422_1_20180110175610.png' width='206' height='30' alt='연합뉴스TV 뉴스리뷰' title='' class='' >",
# "officeName" : "연합뉴스TV",
# "title" : "북한, 개성 남북공동연락사무소 인원 철수",
# "newsKey" : "74f",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/422/2019/03/22/366815.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "북한, 개성 남북공동연락사무소 인원 철수 [뉴스리뷰] [앵커] 북측이 오늘(22일) 오전 상부 지시를 이유로 개성 남북공동연락사무소 철수를 통보했습니다. 우리 정부는 유감을 표시하는 한편 북측에 조속한 복귀를 촉구했",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "449",
# "articleId" : "0000168207",
# "sectionId" : "74b",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/449/2018/01/10/logo_449_1_20180110175910.png' width='206' height='30' alt='채널A 뉴스A' title='' class='' >",
# "officeName" : "채널A",
# "title" : "北, 개성 연락사무소 일방 통보 후 철수…190일 만에 ‘반쪽’",
# "newsKey" : "74b",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/449/2019/03/22/168207.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "여러분 안녕하십니까? 하노이 정상회담이 깨진 뒤 위태위태하던 한반도 안보상황에 북한이 돌발적인 결정을 내렸습니다. 북한은 오늘 개성 남북 공동연락 사무소에서 일방적으로 철수했습니다. 지난해 봄 남북 정상이 합의했고,",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "437",
# "articleId" : "0000205724",
# "sectionId" : "742",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/437/2018/01/10/logo_437_1_20180110175610.png' width='206' height='30' alt='JTBC 뉴스룸' title='' class='' >",
# "officeName" : "JTBC",
# "title" : "김은경 전 환경장관 영장…산하 임원 \'사퇴 압력\' 혐의",
# "newsKey" : "742",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/437/2019/03/22/205724.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[앵커] 산하기관의 임원을 교체한 의혹을 수사 중인 검찰이 김은경 전 환경부 장관에 대해 구속영장을 청구했습니다. 검찰은 청와대와 환경부가 지난 정부에서 임명된 환경부 산하기관 임원들의 사퇴를 종용한 정황을 확인한 ",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "056",
# "articleId" : "0010683551",
# "sectionId" : "355",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/056/2018/01/10/logo_056_1_20180110175610.png' width='206' height='30' alt='KBS 뉴스9' title='' class='' >",
# "officeName" : "KBS",
# "title" : "北 개성연락사무소 전격 철수…“복귀 촉구, 남측 인원은 상주”",
# "newsKey" : "355",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/056/2019/03/22/10683551.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[앵커] 비핵화 협상을 놓고 북미 간의 신경전이 길어지는가 싶더니, 이제 남북관계에도 빨간불이 켜졌습니다. 북측이 오늘(22일) 개성 남북연락사무소에서 일방적으로 인원을 전격 철수시켰습니다. \'상부의 지시에 따른 것",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "214",
# "articleId" : "0000934495",
# "sectionId" : "370",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/214/2018/01/10/logo_214_1_20180110175710.png' width='206' height='30' alt='MBC 뉴스데스크' title='' class='' >",
# "officeName" : "MBC",
# "title" : "北 연락사무소 철수 \"상부 지시로\"…상주하던 15명 즉시 떠나",
# "newsKey" : "370",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/214/2019/03/22/934495.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[뉴스데스크]◀ 앵커 ▶ 여러분, 안녕하십니까. 하노이 북-미 정상회담 결렬 이후, 북한과 미국 사이 드리웠던 먹구름이 끝내 한반도로 번지고 있습니다. 작년 4.27 판문점 남북 정상회담 합의로 문을 열었던 남북 공",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "057",
# "articleId" : "0001335906",
# "sectionId" : "74e",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/057/2018/01/10/logo_057_1_20180110175810.png' width='206' height='30' alt='MBN 뉴스8' title='' class='' >",
# "officeName" : "MBN",
# "title" : "북한, 개성 연락사무소 철수…정부 \"정상운영 희망\"",
# "newsKey" : "74e",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/057/2019/03/22/1335906.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "【 앵커멘트 】 북한이 오늘 개성 남북연락사무소에서 일방적으로 철수했습니다. 정부는 유감을 표하면서 북한이 조속히 복귀하길 바란다고 밝혔습니다. 송주영 기자입니다. 【 기자 】 북한이 남북 연락대표 간 접촉을 통해 ",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "055",
# "articleId" : "0000719037",
# "sectionId" : "371",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/055/2018/01/10/logo_055_1_20180110175610.png' width='206' height='30' alt='SBS 8뉴스' title='' class='' >",
# "officeName" : "SBS",
# "title" : "오늘의 주요뉴스",
# "newsKey" : "371",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/055/2019/03/22/719037.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "1. 북한이 4·27 판문점 선언에 따라 지난해 9월 개성에 문을 연 남북연락사무소에서 상부 지시라며 전격 철수했습니다. 우리 정부는 유감을 표시하면서 연락사무소가 정상 운영되기를 희망한다고 밝혔습니다. ▶ 北, 남",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "448",
# "articleId" : "0000269906",
# "sectionId" : "750",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/448/2018/08/30/logo_448_1_20180830162730.png' width='206' height='30' alt='TV조선 뉴스9' title='' class='' >",
# "officeName" : "TV조선",
# "title" : "北, 개성연락사무소 철수…남북 정상 합의 파기",
# "newsKey" : "750",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/448/2019/03/22/269906.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[앵커] 북한이 개성 남북연락사무소에서 철수하겠다고 일방적으로 통보해 왔습니다. 작년 9월 14일 개소한 뒤 6개월이 조금 지났고, 하노이 미북 정상회담이 결렬된 지 3주 만입니다. 그러나 연락사무소를 폐쇄하지는 않",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "052",
# "articleId" : "0001269460",
# "sectionId" : "751",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/052/2018/01/10/logo_052_1_20180110175810.png' width='206' height='30' alt='YTN 뉴스나이트' title='' class='' >",
# "officeName" : "YTN",
# "title" : "北, 개성 남북연락사무소서 전격 철수...\"상부 지시\"",
# "newsKey" : "751",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/052/2019/03/23/1269460.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "북측이 어제 개성 남북연락사무소에서 전격 철수했습니다. 통일부는 북측이 어제 오전 9시 15분쯤 남북 연락대표 간 접촉을 통해 상부의 지시라며 이런 입장을 통보한 뒤 철수했다고 밝혔습니다. 상주하던 북측 인력은 간단",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# }
# ]
# };
# </script>
# </div>
# <script type="text/javascript">
# 	// page onload 시에 home timelate에서 사용하는 스크립트를 초기화 시켜준다.
# 	jindo.$Fn(function(){
# 		try {
# 			news.home.TopTimelate.Controller.init(_oTopComponentData);
# 		} catch (e) { }
# 	}).attach(window, "load");
# </script>
# <div class="main_space"></div>
# <div class="main" id="container">
# <hr/>
# <div class="main_content main_content_new" id="main_content">
# <div class="main_component droppable" id="today_main_news">
# <div class="com_header">
# <h4 class="tit_h4 tit_main1"><strong>이 시각 주요뉴스</strong></h4>
# <span class="small">최종 <em>2019.03.23 14:15</em></span>
# </div>
# <div id="pan_today_main_news">
# <div class="newsnow" style="position:relative;">
# <div class="newsnow_imgarea">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=001&amp;sid1=102&amp;aid=0010713076&amp;mid=shm&amp;mode=LSD&amp;nh=20190323125943"> <img alt="'삼나무숲 훼손 논란' 제주 비자림로 확장공사 7개월 만에 재개" height="190" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_300x190.png';" src="https://imgnews.pstatic.net/image/upload/item/2019/03/23/125941666_Untitled-22.jpg?type=f270_166" width="300">
# <div class="newsnow_img_mask">
# <div class="newsnow_img_mask_bg"></div>
# <p class="newsnow_img_mask_p"> '삼나무숲 훼손 논란' 제주 비자림로 확장공사 7개월 만에 재개</p>
# </div>
# <div class="newsnow_edge"></div> </img></a>
# </div>
# <ul class="newsnow_txarea" id="text_today_main_news_801001">
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=100&amp;gid=1079155&amp;mid=hot&amp;viewType=pc&amp;cid=1079165&amp;nh=20190323135113"><strong>추가 대북제재 막아 선 트럼프…북한 호응 얻을까</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=003&amp;sid1=102&amp;aid=0009130102&amp;mid=shm&amp;mode=LSD&amp;nh=20190323134832"><strong>미묘한 시기에…김학의, 심야시간 해외출국 시도 왜?</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=003&amp;sid1=100&amp;aid=0009130046&amp;mid=shm&amp;mode=LSD&amp;nh=20190323125340"><strong>與 "환경부장관 구속영장 유감" 野 "블랙리스트 윗선 누구냐"</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=003&amp;sid1=101&amp;aid=0009130007&amp;mid=shm&amp;mode=LSD&amp;nh=20190323110000"><strong>전국 휘발유·경유 가격 5주 연속↑…'본격 상승국면 진입'</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=422&amp;sid1=103&amp;aid=0000366887&amp;mid=shm&amp;mode=LSD&amp;nh=20190323130117"><strong>주말에도 꽃샘 추위…전국 요란한 비·눈</strong></a>
# </div> </li>
# </ul>
# </div>
# <div class="newsnow" style="position:relative;display:block;">
# <div class="newsnow_imgarea">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=008&amp;sid1=101&amp;aid=0004193060&amp;mid=shm&amp;mode=LSD&amp;nh=20190323140454"> <img alt="&quot;신재생에너지 새 강자&quot;라던 지열발전…'총체적 부실'에 주저앉다" height="190" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_300x190.png';" src="https://imgnews.pstatic.net/image/upload/item/2019/03/23/140453239_Untitled-26.jpg?type=f270_166" width="300">
# <div class="newsnow_img_mask">
# <div class="newsnow_img_mask_bg"></div>
# <p class="newsnow_img_mask_p"> "신재생에너지 새 강자"라던 지열발전…'총체적 부실'에 주저앉다</p>
# </div>
# <div class="newsnow_edge"></div> </img></a>
# </div>
# <ul class="newsnow_txarea" id="text_today_main_news_428288">
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=001&amp;sid1=102&amp;aid=0010713074&amp;mid=shm&amp;mode=LSD&amp;nh=20190323131225"><strong>"1980년대 초미세먼지, 현재 4배…2013년부터 감소 추세 멈춰"</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=001&amp;sid1=102&amp;aid=0010712977&amp;mid=shm&amp;mode=LSD&amp;nh=20190323111815"><strong>'버닝썬 금고지기' 경리실장 돌연 해외 잠적…경찰, 행방 추적</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=052&amp;sid1=100&amp;aid=0001269586&amp;mid=shm&amp;mode=LSD&amp;nh=20190323135159"><strong>4·3 보궐선거 선거운동 첫 주말…창원 성산 '대격돌'</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=001&amp;sid1=102&amp;aid=0010713185&amp;mid=shm&amp;mode=LSD&amp;nh=20190323141027"><strong>부가티·돈가방·매매증서…'이희진 부모살해' 사건의 재구성</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=366&amp;sid1=101&amp;aid=0000429837&amp;mid=shm&amp;mode=LSD&amp;nh=20190323125713"><strong>저물가가 어때서…선제적 대응 나선 각국 중앙은행</strong></a>
# </div> </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclicks(hom.order)" title="이동">이동</span>
# <a class="up_off nclicks(hom.order)" href="#" title="위로">위로</a>
# <a class="down nclicks(hom.order)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_politics">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(pol.title)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h4>
# <span class="tit_sub">
# <a class="nclicks(pol.common)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">일반</a><span class="bar"></span>
# <a class="nclicks(pol.party)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당</a><span class="bar"></span>
# <a class="nclicks(pol.chung)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">청와대</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','88000127_000000000000000009130090', 'airsGParam', '0', 'news_sec_v2.0', 'ii4eClrD5MhhwR61')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0009130090">
# <img alt="나흘간 대정부질문 '김빠진 사이다'…'사이다 총리'만 부각" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/003/2019/03/23/9130090.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','88000127_000000000000000009130090', 'airsGParam', '0', 'news_sec_v2.0', 'ii4eClrD5MhhwR61')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0009130090">나흘간 대정부질문 '김빠진 사이다'…'사이다 총리'만 부각</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','88000127_000000000000000009130090', 'airsGParam', '0', 'news_sec_v2.0', 'ii4eClrD5MhhwR61')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0002893714">
# <strong>“황교안 단단히 화났다”…‘김학의 네거티브’에 법적 대응할까</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">중앙일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000127_000000000000000009130090', 'airsGParam', '0', 'news_sec_v2.0', 'ii4eClrD5MhhwR61')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=119&amp;aid=0002318574">
# <strong>[北핵, 살길을 찾자①] 핵없이 핵을 이기는 법</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">데일리안</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000127_000000000000000009130090', 'airsGParam', '0', 'news_sec_v2.0', 'ii4eClrD5MhhwR61')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=057&amp;aid=0001336031">
# <strong>이해찬 "황교안, 김학의 사건 모른다는 게 말이 되나" 직격탄</strong>
# </a>
# <span class="writing">MBN</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000127_000000000000000009130090', 'airsGParam', '0', 'news_sec_v2.0', 'ii4eClrD5MhhwR61')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=421&amp;aid=0003897225">
# <strong>대정부질문 '방패' 이낙연…톡 쏘는 '사이다' 답변에 김빠진 野</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">뉴스1</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000127_000000000000000009130090', 'airsGParam', '0', 'news_sec_v2.0', 'ii4eClrD5MhhwR61')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=119&amp;aid=0002318573">
# <strong>"색깔론"vs"악법전문가"…궁합 안맞는 이해찬·황교안</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">데일리안</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(soc.move)" title="이동">이동</span>
# <a class="up nclicks(soc.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(soc.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_economy">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(eco.title)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=101">경제</a></h4>
# <span class="tit_sub">
# <a class="nclicks(eco.common)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=263">일반</a><span class="bar"></span>
# <a class="nclicks(eco.finance)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=259">금융</a><span class="bar"></span>
# <a class="nclicks(eco.domestic)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=310">생활경제</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','880000E7_000000000000000004337058', 'airsGParam', '0', 'news_sec_v2.0', '6aIFtMet6adBFq1c')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=018&amp;aid=0004337058">
# <img alt='"똘똘한 집 한채로 크게 굴려라"…부.알.못의 아파트 투자 성공기' height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/018/2019/03/23/4337058.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','880000E7_000000000000000004337058', 'airsGParam', '0', 'news_sec_v2.0', '6aIFtMet6adBFq1c')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=018&amp;aid=0004337058">"똘똘한 집 한채로 크게 굴려라"…부.알.못의 아파트 투자 성공기</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','880000E7_000000000000000004337058', 'airsGParam', '0', 'news_sec_v2.0', '6aIFtMet6adBFq1c')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=018&amp;aid=0004337054">
# <strong>[아파트 돋보기]전기요금은 왜  한전에서 직접 부과하지 않나?</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">이데일리</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000E7_000000000000000004337058', 'airsGParam', '0', 'news_sec_v2.0', '6aIFtMet6adBFq1c')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=018&amp;aid=0004337052">
# <strong>제3 인터넷은행 ‘토스뱅크’ 나올 수 있을까</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">이데일리</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000E7_000000000000000004337058', 'airsGParam', '0', 'news_sec_v2.0', '6aIFtMet6adBFq1c')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=003&amp;aid=0009130078">
# <strong>조선업 재편 한창이지만 중형 조선사는 '고사 위기'</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">뉴시스</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000E7_000000000000000004337058', 'airsGParam', '0', 'news_sec_v2.0', '6aIFtMet6adBFq1c')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=469&amp;aid=0000374404">
# <strong>파트너 잃은 토스은행, 인터넷은행 인가 따낼 수 있을까</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">한국일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000E7_000000000000000004337058', 'airsGParam', '0', 'news_sec_v2.0', '6aIFtMet6adBFq1c')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=277&amp;aid=0004435600">
# <strong>대기업 25% 실적 줄었는데 배당 늘렸다…배당 둘러싼 '온도 차'(종합)</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">아시아경제</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(pol.move)" title="이동">이동</span>
# <a class="up nclicks(pol.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(pol.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_society">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(soc.title)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=102">사회</a></h4>
# <span class="tit_sub">
# <a class="nclicks(soc.common)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=257">일반</a><span class="bar"></span>
# <a class="nclicks(soc.edu)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=250">교육</a><span class="bar"></span>
# <a class="nclicks(soc.labor)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=251">노동</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','8800006B_000000000000000002930236', 'airsGParam', '0', 'news_sec_v2.0', 'STpn8XGCs6BB0fzZ')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=032&amp;aid=0002930236">
# <img alt="[단독]이문호 버닝썬 대표 “승리 지분 20%는 공짜(상여)로 준 것”" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/032/2019/03/23/2930236.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','8800006B_000000000000000002930236', 'airsGParam', '0', 'news_sec_v2.0', 'STpn8XGCs6BB0fzZ')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=032&amp;aid=0002930236">[단독]이문호 버닝썬 대표 “승리 지분 20%는 공짜(상여)로 준 것”</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','8800006B_000000000000000002930236', 'airsGParam', '0', 'news_sec_v2.0', 'STpn8XGCs6BB0fzZ')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=001&amp;aid=0010713185">
# <strong>부가티ㆍ돈가방ㆍ매매증서…'이희진 부모살해' 사건의 재구성</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">연합뉴스</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8800006B_000000000000000002930236', 'airsGParam', '0', 'news_sec_v2.0', 'STpn8XGCs6BB0fzZ')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=003&amp;aid=0009130114">
# <strong>'세월호 천막' 사라진 첫 주말…"기억공간 만들어 다행"</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">뉴시스</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8800006B_000000000000000002930236', 'airsGParam', '0', 'news_sec_v2.0', 'STpn8XGCs6BB0fzZ')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=421&amp;aid=0003897290">
# <strong>'별장 성접대' 김학의, 수사시작도 전에 어떻게 출국금지 됐나</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">뉴스1</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8800006B_000000000000000002930236', 'airsGParam', '0', 'news_sec_v2.0', 'STpn8XGCs6BB0fzZ')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=023&amp;aid=0003434769">
# <strong>'연예인-경찰 가교 역할' 유리홀딩스 대표 유인석, 정체는?</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">조선일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8800006B_000000000000000002930236', 'airsGParam', '0', 'news_sec_v2.0', 'STpn8XGCs6BB0fzZ')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=003&amp;aid=0009130102">
# <strong>미묘한 시기에…김학의, 심야시간 해외출국 시도 왜?</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">뉴시스</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(eco.move)" title="이동">이동</span>
# <a class="up nclicks(eco.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(eco.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_life">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(lif.title)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=103">생활/문화</a></h4>
# <span class="tit_sub">
# <a class="nclicks(lif.health)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=241">건강</a><span class="bar"></span>
# <a class="nclicks(lif.travel)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=237">여행</a><span class="bar"></span>
# <a class="nclicks(lif.car)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=239">자동차</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','880000E3_000000000000000002221356', 'airsGParam', '0', 'news_sec_v2.0', 'kKFpkCZMGxxwGOXy')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=047&amp;aid=0002221356">
# <img alt="북한사람이라고 빨간 얼굴은 아니었네" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/047/2019/03/23/2221356.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','880000E3_000000000000000002221356', 'airsGParam', '0', 'news_sec_v2.0', 'kKFpkCZMGxxwGOXy')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=047&amp;aid=0002221356">북한사람이라고 빨간 얼굴은 아니었네</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','880000E3_000000000000000002221356', 'airsGParam', '0', 'news_sec_v2.0', 'kKFpkCZMGxxwGOXy')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=421&amp;aid=0003897222">
# <strong>오후 6시까지 전국 비·눈…수도권‧강원영서는 천둥·번개 동반</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">뉴스1</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000E3_000000000000000002221356', 'airsGParam', '0', 'news_sec_v2.0', 'kKFpkCZMGxxwGOXy')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=422&amp;aid=0000366883">
# <strong>세계에서 가장 비싼 작가…호크니 첫 회고전</strong>
# </a>
# <span class="writing">연합뉴스TV</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000E3_000000000000000002221356', 'airsGParam', '0', 'news_sec_v2.0', 'kKFpkCZMGxxwGOXy')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=469&amp;aid=0000374397">
# <strong>‘화유기’부터 ‘빅이슈’까지… 방송사고 부른 ‘생방송 드라마’</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">한국일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000E3_000000000000000002221356', 'airsGParam', '0', 'news_sec_v2.0', 'kKFpkCZMGxxwGOXy')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=055&amp;aid=0000719121">
# <strong>[스브스뉴스] 치킨·족발·닭발 먹을 때 비닐장갑 껴도 손에 기름 묻는 이유</strong>
# </a>
# <span class="writing">SBS</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000E3_000000000000000002221356', 'airsGParam', '0', 'news_sec_v2.0', 'kKFpkCZMGxxwGOXy')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=025&amp;aid=0002893702">
# <strong>"진격의 거인 돼서 청와대 밟고 싶단 대사, 실제 세월호 때…"</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">중앙일보</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(lif.move)" title="이동">이동</span>
# <a class="up nclicks(lif.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(lif.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_world">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(wor.title)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=104">세계</a></h4>
# <span class="tit_sub">
# <a class="nclicks(wor.common)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=104&amp;sid2=322">일반</a><span class="bar"></span>
# <a class="nclicks(wor.issue)" href="/main/hotissue/sectionList.nhn?mid=hot&amp;sid1=104&amp;cid=845614">지구촌 화제</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','880000AF_000000000000000001269584', 'airsGParam', '0', 'news_sec_v2.0', 'TahUTz0yu9a78fVA')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=052&amp;aid=0001269584">
# <img alt='"트럼프 내주 예정 北제재 취소"...대화 동력 유지 포석' height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/052/2019/03/23/1269584.jpg?type=nf220_140" width="220"/>
# <strong class="r_ico r_vod_large">동영상 기사</strong>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','880000AF_000000000000000001269584', 'airsGParam', '0', 'news_sec_v2.0', 'TahUTz0yu9a78fVA')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=052&amp;aid=0001269584">"트럼프 내주 예정 北제재 취소"...대화 동력 유지 포석</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','880000AF_000000000000000001269584', 'airsGParam', '0', 'news_sec_v2.0', 'TahUTz0yu9a78fVA')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=001&amp;aid=0010713169">
# <strong>'대통령 사진 훼손한 죄?'…부룬디 10대 여학생 3명 5년형 직면</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">연합뉴스</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000AF_000000000000000001269584', 'airsGParam', '0', 'news_sec_v2.0', 'TahUTz0yu9a78fVA')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=421&amp;aid=0003897272">
# <strong>中장쑤성 폭발사고로 64명 사망…정부조사단 발족(종합)</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">뉴스1</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000AF_000000000000000001269584', 'airsGParam', '0', 'news_sec_v2.0', 'TahUTz0yu9a78fVA')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=081&amp;aid=0002985633">
# <strong>78세 할머니, 뉴욕지하철서 무차별 폭행당해…승객들은 촬영만</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">서울신문</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000AF_000000000000000001269584', 'airsGParam', '0', 'news_sec_v2.0', 'TahUTz0yu9a78fVA')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=469&amp;aid=0000374403">
# <strong>트윗 하나로 트럼프-참모 간 대북정책 ‘집안 싸움’ 노출</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">한국일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000AF_000000000000000001269584', 'airsGParam', '0', 'news_sec_v2.0', 'TahUTz0yu9a78fVA')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=001&amp;aid=0010713121">
# ...
# jindo.$('BUTTON_ROLLING_NEXT_'+1084855).onclick = function (e){jindo.$Event(e).stopDefault(); rolling_1084855.rolling(rolling_1084855);}
# </script>
# <div class="section">
# <h4 id="ROLLING_TITLE_1078913_0">전문기자 칼럼</h4>
# <span class="cate_navi index_cate_navi"> <a class="il_btn_prev nclicks(rig.column)" href="#" id="BUTTON_ROLLING_PREV_1078913"><span class="blind">이전</span></a><a class="il_btn_next nclicks(rig.column)" href="#" id="BUTTON_ROLLING_NEXT_1078913"><span class="blind">다음</span></a> </span>
# <div class="column" id="includebox_1078913">
# <span id="ROLLING_IMG_1078913_0">
# <div class="column_thumb">
# <a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&amp;sid1=110&amp;cid=1064672&amp;dummy=1712081723"><img alt="김인수 기자의 사람이니까 경영이다" height="92" src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/104425810_100559917_2.jpg" width="300"><span class="trans_border"></span></img></a>
# </div> <h5 class="normal"> <a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&amp;sid1=110&amp;cid=1064672&amp;dummy=1712081723"> 김인수 기자의 사람이니까 경영이다</a> </h5> </span>
# <ul class="type02" id="ROLLING_TEXT_1078913_0">
# </ul>
# </div>
# </div>
# <script type="text/javascript">
# var rolling_1078913;
# function executeRolling1078913() {
# var items = new Array();
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1078994'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&dummy=1712081723&mid=hot&cid=1064672&nh=20190320143714"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/104425810_100559917_2.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1064672&dummy=1712081723" >'
# +'\uAE40\uC778\uC218 \uAE30\uC790\uC758 \uC0AC\uB78C\uC774\uB2C8\uAE4C \uACBD\uC601\uC774\uB2E4</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1078997'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&dummy=1804240001&mid=hot&cid=891791&nh=20180705025147"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/110249340_104120726_1.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=891791&nh=20171201095844&dummy=1804240001" >'
# +'\uD604\uBB38\uD559 \uAE30\uC790\uC758 \uB3C8\uB418\uB294 \uC911\uAD6D\uACBD\uC81C</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1078996'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&dummy=1804240002&mid=hot&cid=1014465&nh=20180705025133"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/04/25/142251923_102308592_1.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1014465&dummy=1804240002" >'
# +'\uCD5C\uAE30\uC131\uC758 \uD5C8\uBE0C\u8ECA</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1078995'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=1008884&nh=20180705025141"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/105836599_140956069_1.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1008884" >'
# +'\uCD5C\uC740\uC218 \uAE30\uC790\uC758 \uBBF8\uB798\uC774\uC57C\uAE30</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1079006'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=1000701&nh=20180705025040"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/104729590_111031797_2.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1000701" >'
# +'\uC548\uB450\uC6D0 \uAE30\uC790\uC758 \uBA3C \uB4EF \uAC00\uAE4C\uC6B4 \uBC29\uC0B0\uC5C5\uCCB4 \uBCA0\uC77C \uBC97\uAE30\uAE30</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1079007'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=103&mid=hot&cid=1047810&nh=20180705025025"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/04/25/141839774_150349068_3.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=103&cid=1047810" >'
# +'\uBC30\uD55C\uCCA0 \uAE30\uC790\uC758 \uD55C\uAD6D\uCD08\uC0C1\uD654 \uD1BA\uC544\uBCF4\uAE30</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1078915'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=1024480&nh=20180705025102"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/104847598_092210791_1.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1024480" >'
# +'\uC774\uC9C4\uC6B0 \uAE30\uC790\uC758 \uC808\uBCBD\uAC00(\u7D76\u58C1\u6B4C)</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1079008'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=1081825&nh=20180816121231"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/04/25/141636888_0002407462_001_20180424201007021.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1081825" >'
# +'\uC591\uC120\uC544 \uAE30\uC790\uC758 \uC0DD\uC0DD\uC721\uC544</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1079054'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=103&mid=hot&cid=74098&nh=20180705025155"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/110207694_0002411839_002_20180530210508428.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=103&cid=74098" >'
# +'\uACFD\uC724\uC12D \uAE30\uC790\uC758 \uC0AC\uC9C4\uB9C8\uC744</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1078993'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&dummy=1711271013&mid=hot&cid=1064671&nh=20180705024959"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/104600244_174451333_1.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1064671&dummy=1711271013" >'
# +'\uAE40\uC885\uCCA0 \uAE30\uC790\uC758 \uD4E8\uC804 \uB9AC\uB354\uC2ED&\uB864\uBAA8\uB378</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1078903'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=1064777&nh=20180705025014"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/104638178_0002413936_001_20180615163006322.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1064777" >'
# +'\uACFD\uB178\uD544 \uAE30\uC790\uC758 \uBBF8\uB798\uCC3D</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# rolling_1078913 = new news.common.Rolling({'rollingItems':items, 'showId':'ROLLING', 'rollingCount':1, 'interval':0, 'isEffectAppear':false});
# }
# executeRolling1078913();
# jindo.$('BUTTON_ROLLING_PREV_'+1078913).onclick = function (e){jindo.$Event(e).stopDefault(); rolling_1078913.backRolling(rolling_1078913);}
# jindo.$('BUTTON_ROLLING_NEXT_'+1078913).onclick = function (e){jindo.$Event(e).stopDefault(); rolling_1078913.rolling(rolling_1078913);}
# </script>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.nhn"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.nhn?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.nhn?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&amp;sid1=100&amp;cid=909906&amp;decorator=ombudsman&amp;confirm=true"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.nhn"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <div class="da" id="rightDoubleDA" style="display: none"></div>
# <script type="text/javascript">
#             try{
#                 jindo.$("doubleDA").innerHTML = '<div id="daHome_300250" name="daHome_300250" style="width: 300px; height: 250px;"><iframe id="home300250" name="home300250" src="https://veta.naver.com/fxshow?su=SU10306&calp=home" width="300" height="250" marginheight="0" marginwidth="0" border="0" frameborder="0" scrolling="no" align="center" title="우측_뉴스홈_더블플레이광고" data-veta-preview="news_home_02"></iframe></div>';
#             }catch(e){}
#         </script>
# <div class="rightBottomDouble" style="margin-top:36px;"><div data-dom-type="doubleplay_bottom" id="doubleHome300250" name="doubleHome300250" title="더블플레이하단광고"></div></div>
# </div>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# <div class="index_myscrap">
# <a class="spr nclicks(fot.scrap)" href="/main/scrap/index.nhn">마이스크랩</a>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.nhn">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.nhn?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 정연아</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
# new news.lnb.NewsSearchController('lnb.searchForm');
#
#
#
# //var lnb_weatherRolling = new news.lnb.LineRolling('lnb.weather',{size:26,moveSize:3,moveInterval:30});
# var lnb_mainnewsRolling = new news.lnb.LineRolling('lnb.mainnews',{size:17,moveSize:2,moveInterval:30,isRandomStart:true});
# var lnb_Rolling = new news.lnb.SynchronizedRolling({interval:3000});
# //lnb_Rolling.push(lnb_weatherRolling);
# lnb_Rolling.push(lnb_mainnewsRolling);
# lnb_Rolling.start();
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.nhn'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.nhn'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#
#
#
# news.home.DragController.init();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </div>
# </body>
# </html>

# %%
ul = bs_obj.find("ul", {"id":"text_today_main_news_801001"})

# %%
ul
# Out:
# <ul class="newsnow_txarea" id="text_today_main_news_801001">
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=100&amp;gid=1079155&amp;mid=hot&amp;viewType=pc&amp;cid=1079165&amp;nh=20190323135113"><strong>추가 대북제재 막아 선 트럼프…북한 호응 얻을까</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=003&amp;sid1=102&amp;aid=0009130102&amp;mid=shm&amp;mode=LSD&amp;nh=20190323134832"><strong>미묘한 시기에…김학의, 심야시간 해외출국 시도 왜?</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=003&amp;sid1=100&amp;aid=0009130046&amp;mid=shm&amp;mode=LSD&amp;nh=20190323125340"><strong>與 "환경부장관 구속영장 유감" 野 "블랙리스트 윗선 누구냐"</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=003&amp;sid1=101&amp;aid=0009130007&amp;mid=shm&amp;mode=LSD&amp;nh=20190323110000"><strong>전국 휘발유·경유 가격 5주 연속↑…'본격 상승국면 진입'</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=422&amp;sid1=103&amp;aid=0000366887&amp;mid=shm&amp;mode=LSD&amp;nh=20190323130117"><strong>주말에도 꽃샘 추위…전국 요란한 비·눈</strong></a>
# </div> </li>
# </ul>

# %%
lis = ul.findAll("li")

# %%
print(lis)
# Out:
# [<li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=100&amp;gid=1079155&amp;mid=hot&amp;viewType=pc&amp;cid=1079165&amp;nh=20190323135113"><strong>추가 대북제재 막아 선 트럼프…북한 호응 얻을까</strong></a>
# </div> </li>, <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=003&amp;sid1=102&amp;aid=0009130102&amp;mid=shm&amp;mode=LSD&amp;nh=20190323134832"><strong>미묘한 시기에…김학의, 심야시간 해외출국 시도 왜?</strong></a>
# </div> </li>, <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=003&amp;sid1=100&amp;aid=0009130046&amp;mid=shm&amp;mode=LSD&amp;nh=20190323125340"><strong>與 "환경부장관 구속영장 유감" 野 "블랙리스트 윗선 누구냐"</strong></a>
# </div> </li>, <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=003&amp;sid1=101&amp;aid=0009130007&amp;mid=shm&amp;mode=LSD&amp;nh=20190323110000"><strong>전국 휘발유·경유 가격 5주 연속↑…'본격 상승국면 진입'</strong></a>
# </div> </li>, <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=422&amp;sid1=103&amp;aid=0000366887&amp;mid=shm&amp;mode=LSD&amp;nh=20190323130117"><strong>주말에도 꽃샘 추위…전국 요란한 비·눈</strong></a>
# </div> </li>]

# %%
print(datetime.datetime.now())
for li in lis:
    strong = li.find("strong")
    print(strong.text)
# Out:
# 2019-03-23 14:26:57.507894
# 추가 대북제재 막아 선 트럼프…북한 호응 얻을까
# 미묘한 시기에…김학의, 심야시간 해외출국 시도 왜?
# 與 "환경부장관 구속영장 유감" 野 "블랙리스트 윗선 누구냐"
# 전국 휘발유·경유 가격 5주 연속↑…'본격 상승국면 진입'
# 주말에도 꽃샘 추위…전국 요란한 비·눈
